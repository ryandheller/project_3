# %%
import pandas as pd
import concurrent.futures
import urllib.request
from bs4 import BeautifulSoup
from datetime import datetime
import requests
import glob
import pickle
from sklearn.metrics import accuracy_score, log_loss
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
import pymongo
from pymongo import MongoClient

# %%
score_url_dates = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]
urls = []
for dat in score_url_dates:
    date = f'https://www.hockey-reference.com/leagues/NHL_{dat}_games.html'
    urls.append(date)
dfs = []
for url in urls:
    page = pd.read_html(url)
    dfs.append(page[0])
df = pd.concat([dfs[i] for i in range(len(dfs))])

# %%
df.columns = ['Date','Away','VG','Home','HG','OT','ATT','LOG','Notes']
results_df = df[['Date','Away','VG','Home','HG','OT','ATT']]

# %%
odds_date_list = []
for df in dfs:
    dates = list(df['Date'].unique())
    for date in dates:
        odds_date_list.append(date)

# %%
oddss = {}
for date in odds_date_list:
    broken = date.replace('-','')
    url = f'https://www.sportsbookreview.com/betting-odds/nhl-hockey/?date={broken}'
    oddss[date] = url

# %%
oddss_urls = []
for k,v in oddss.items():
    oddss_urls.append(v)
len(oddss_urls)
# Out:
# 1690

# %%
existing_filed = [x for x in glob.glob('htmlFolder/*.html')]
def load_html(url):
    fullname = "htmlFolder\ "+ url.split('=')[1] + ".html"
    if fullname not in existing_filed:
        resp = requests.get(url)
        soup = BeautifulSoup(resp.text,"html.parser")
#         fullname = "htmlFolder\ "+ url.split('=')[1] + ".html"
        with open(fullname, 'w', encoding="utf-8") as f:
            f.write(str(soup))

with concurrent.futures.ThreadPoolExecutor(max_workers=6) as executor:
    # Start the load operations and mark each future with its URL
    future_to_url = {executor.submit(load_html, url): url for url in oddss_urls}
    for future in concurrent.futures.as_completed(future_to_url):
        url = future_to_url[future]
        try:
            data = future.result()
        except Exception as exc:  'a'
#             print('%r generated an exception: %s' % (url, exc))
        else:  'b'
        
for url in odds_urls:
    load_html(url)

# %%
existing_files = [x for x in glob.glob('htmlFolder/*.html')]
z= []
list_o_dicts = {}
allGames = []
count = 0
for file in existing_files:
    date_pre = file.split('\\')[1].split('.')[0].split(' ')[1]
    date = date_pre[:4] + '-' + date_pre[4:6] + '-' + date_pre[6:]
    if date not in list_o_dicts.keys():
        list_o_dicts[date] = []
    with open(file, 'r', encoding='utf-8') as f:
        soup = BeautifulSoup(f, "html.parser")
        idk = soup.find_all('span',{'class':'opener'})
        idx = soup.find_all('span')
#     resp = requests.get(file)
#     soup = BeautifulSoup(resp.text,"html.parser")
#     idk = soup.find_all('span',{'class':'opener'})
        x = [str(i) for i in idk]
        x = [i for i in x if i!='<span class="opener">-</span>']
        c = 0
        l=[]
        #     final = []
        for i in x:
            val = i.split(">")[1].split("<")[0]
            if '%' not in val:
                l.append(val)
    #         l.append(val)
    #     print(l)
    #     idx = soup.find_all('span')
        idx = [str(i) for i in idx if 'class="_3O1Gx"' in str(i)]
        j = []
        for ik in idx:
            vals = ik.split('>')[1].split('<')[0]
            j.append(vals)
    #     print(j)
        aa = list(zip(j,l))
        mess = []
        for a in aa:
            z.append(a)
            c+=1
            if c%2==0:
                mess.append(z)
                z = []
        bigger_dict = []
        for mes in mess:
            away = mes[0][0]
            home = mes[1][0]
            h_odd = mes[1][1]
            a_odd = mes[0][1]
            smol_dict = {'Home':home,'Away':away,'H_odd':h_odd,"A_odd":a_odd}
            tempDict = smol_dict.copy()
            tempDict["Date"]= date
            allGames.append(tempDict)
            bigger_dict.append(smol_dict)
        list_o_dicts[date].extend(bigger_dict)
        pop = {date:bigger_dict}
        list_o_dicts[date] = bigger_dict
        count +=1
#         print(count)
len(allGames)
# Out:
# 11844

# %%
odds_df = pd.DataFrame(allGames)
odds_df.shape
# Out:
# (11844, 5)

# %%
odds_df["Home"] = odds_df["Home"].apply(lambda x: "Detroit" if x=="Unknown" else x)
odds_df["Away"] = odds_df["Away"].apply(lambda x: "Toronto" if x=="Unknown" else x)
odds_df[odds_df['Away']=='Unknown'],odds_df[odds_df['Home']=='Unknown']
# Out:
# (Empty DataFrame
#  Columns: [A_odd, Away, Date, H_odd, Home]
#  Index: [], Empty DataFrame
#  Columns: [A_odd, Away, Date, H_odd, Home]
#  Index: [])

# %%
team_names = list(results_df['Away'].unique())
city_names = list(odds_df['Away'].unique())

# %%
city_to_team_dict = {}
city_to_team_dict['Anaheim'] = 'Anaheim Ducks'
city_to_team_dict['Arizona'] = 'Arizona Coyotes'
city_to_team_dict['Boston'] = 'Boston Bruins'
city_to_team_dict['Buffalo'] = 'Buffalo Sabres'
city_to_team_dict['Calgary'] = 'Calgary Flames'
city_to_team_dict['Carolina'] = 'Carolina Hurricanes'
city_to_team_dict['Chicago'] = 'Chicago Blackhawks'
city_to_team_dict['Colorado'] = 'Colorado Avalanche'
city_to_team_dict['Columbus'] = 'Columbus Blue Jackets'
city_to_team_dict['Dallas'] = 'Dallas Stars'
city_to_team_dict['Detroit'] = 'Detroit Red Wings'
city_to_team_dict['Edmonton'] = 'Edmonton Oilers'
city_to_team_dict['Florida'] = 'Florida Panthers'
city_to_team_dict['Los Angeles'] = 'Los Angeles Kings'
city_to_team_dict['Minnesota'] = 'Minnesota Wild'
city_to_team_dict['Montreal'] = 'Montreal Canadiens'
city_to_team_dict['N.Y. Islanders'] = 'New York Islanders'
city_to_team_dict['N.Y. Rangers'] = 'New York Rangers'
city_to_team_dict['Nashville'] = 'Nashville Predators'
city_to_team_dict['New Jersey'] = 'New Jersey Devils'
city_to_team_dict['Ottawa'] = 'Ottawa Senators'
city_to_team_dict['Philadelphia'] = 'Philadelphia Flyers'
city_to_team_dict['Pittsburgh'] = 'Pittsburgh Penguins'
city_to_team_dict['San Jose'] = 'San Jose Sharks'
city_to_team_dict['St. Louis'] = 'St Louis Blues'
city_to_team_dict['Tampa Bay'] = 'Tampa Bay Lightning'
city_to_team_dict['Toronto'] = 'Toronto Maple Leafs'
city_to_team_dict['Vancouver'] = 'Vancouver Canucks'
city_to_team_dict['Vegas'] = 'Vegas Golden Knights'
city_to_team_dict['Washington'] = 'Washington Capitals'
city_to_team_dict['Winnipeg'] = 'Winnipeg Jets'

# %%
rename_dict = {}
rename_dict['Anaheim Ducks'] = 'Anaheim Ducks'
rename_dict['Arizona Coyotes'] = 'Arizona Coyotes'
rename_dict['Atlanta Thrashers'] = 'Winnipeg Jets'
rename_dict['Boston Bruins'] = 'Boston Bruins'
rename_dict['Buffalo Sabres'] = 'Buffalo Sabres'
rename_dict['Calgary Flames'] = 'Calgary Flames'
rename_dict['Carolina Hurricanes'] = 'Carolina Hurricanes'
rename_dict['Chicago Blackhawks'] = 'Chicago Blackhawks'
rename_dict['Colorado Avalanche'] = 'Colorado Avalanche'
rename_dict['Columbus Blue Jackets'] = 'Columbus Blue Jackets'
rename_dict['Dallas Stars'] = 'Dallas Stars'
rename_dict['Detroit Red Wings'] = 'Detroit Red Wings'
rename_dict['Edmonton Oilers'] = 'Edmonton Oilers'
rename_dict['Florida Panthers'] = 'Florida Panthers'
rename_dict['Los Angeles Kings'] = 'Los Angeles Kings'
rename_dict['Minnesota Wild'] = 'Minnesota Wild'
rename_dict['Montreal Canadiens'] = 'Montreal Canadiens'
rename_dict['Nashville Predators'] = 'Nashville Predators'
rename_dict['New York Rangers'] = 'New York Rangers'
rename_dict['New York Islanders'] = 'New York Islanders'
rename_dict['Ottawa Senators'] = 'Ottawa Senators'
rename_dict['Philadelphia Flyers'] = 'Philadelphia Flyers'
rename_dict['Phoenix Coyotes'] = 'Arizona Coyotes'
rename_dict['Pittsburgh Penguins'] = 'Pittsburgh Penguins'
rename_dict['San Jose Sharks'] = 'San Jose Sharks'
rename_dict['St. Louis Blues'] = 'St Louis Blues'
rename_dict['Tampa Bay Lightning'] = 'Tampa Bay Lightning'
rename_dict['Toronto Maple Leafs'] = 'Toronto Maple Leafs'
rename_dict['Vancouver Canucks'] = 'Vancouver Canucks'
rename_dict['Vegas Golden Knights'] = 'Vegas Golden Knights'
rename_dict['Washington Capitals'] = 'Washington Capitals'
rename_dict['Winnipeg Jets'] = 'Winnipeg Jets'
rename_dict['New Jersey Devils'] = 'New Jersey Devils'
set(list(city_to_team_dict.values())) == set(list(rename_dict.values()))
# Out:
# True

# %%
ML_dict = {}
ML_dict['Anaheim Ducks'] = 1
ML_dict['Arizona Coyotes'] = 2
ML_dict['Boston Bruins'] = 3
ML_dict['Buffalo Sabres'] = 4
ML_dict['Calgary Flames'] = 5
ML_dict['Carolina Hurricanes'] = 6
ML_dict['Chicago Blackhawks'] = 7
ML_dict['Colorado Avalanche'] = 8
ML_dict['Columbus Blue Jackets'] = 9
ML_dict['Dallas Stars'] = 10
ML_dict['Detroit Red Wings'] = 11
ML_dict['Edmonton Oilers'] = 12
ML_dict['Florida Panthers'] = 13
ML_dict['Los Angeles Kings'] = 14
ML_dict['Minnesota Wild'] = 15
ML_dict['Montreal Canadiens'] = 16
ML_dict['Nashville Predators'] = 17
ML_dict['New Jersey Devils'] = 18
ML_dict['New York Rangers'] = 19
ML_dict['New York Islanders'] = 20
ML_dict['Ottawa Senators'] = 21
ML_dict['Philadelphia Flyers'] = 22
ML_dict['Pittsburgh Penguins'] = 23
ML_dict['San Jose Sharks'] = 24
ML_dict['St Louis Blues'] = 25
ML_dict['Tampa Bay Lightning'] = 26
ML_dict['Toronto Maple Leafs'] = 27
ML_dict['Vancouver Canucks'] = 28
ML_dict['Vegas Golden Knights'] = 29
ML_dict['Washington Capitals'] = 30
ML_dict['Winnipeg Jets'] = 31
num_to_team = {v:k for k,v in ML_dict.items()}

# %%
odds_df["Home"] = odds_df["Home"].apply(lambda x: city_to_team_dict[x])
odds_df["Away"] = odds_df["Away"].apply(lambda x: city_to_team_dict[x])
# odds_df.head()
# Out:
#    A_odd                 Away        Date H_odd                 Home
# 0   +110   Montreal Canadiens  2009-10-01  -130  Toronto Maple Leafs
# 1   +115  Washington Capitals  2009-10-01  -135        Boston Bruins
# 2   -175      San Jose Sharks  2009-10-01  +155   Colorado Avalanche
# 3   +115    Vancouver Canucks  2009-10-01  -135       Calgary Flames
# 4   +140     Florida Panthers  2009-10-02  -160   Chicago Blackhawks
# 5   +125       St Louis Blues  2009-10-02  -145    Detroit Red Wings
# 6   +100  Philadelphia Flyers  2009-10-02  -120  Carolina Hurricanes
# 7   +140     New York Rangers  2009-10-02  -160  Pittsburgh Penguins
# 8   -145   Chicago Blackhawks  2009-10-03  +125     Florida Panthers
# 9   -170    Detroit Red Wings  2009-10-03  +150       St Louis Blues
# 10  -145    Vancouver Canucks  2009-10-03  +125   Colorado Avalanche
# 11  +120  Philadelphia Flyers  2009-10-03  -140    New Jersey Devils
# 12  +165  Carolina Hurricanes  2009-10-03  -190        Boston Bruins
# 13  +135   Montreal Canadiens  2009-10-03  -155       Buffalo Sabres
# 14  -170  Pittsburgh Penguins  2009-10-03  +150   New York Islanders

# %%
odds_sorted = odds_df.sort_values(by=['Date','Home','Away'])
results_sorted = results_df.sort_values(by=['Date','Home','Away'])

# %%
odds_and_results_df = odds_sorted.merge(results_sorted, left_on=['Date','Home'], right_on=['Date','Home'], how='inner')

endings = []
for row in odds_and_results_df.iterrows():
    if row[1][8] == 'OT':
        endings.append('OT')
    elif row[1][8] == 'SO':
        endings.append('SO')
    else: endings.append('REG')
odds_and_results_df['OT'] = endings
odds_and_results_df['Winner'] = odds_and_results_df['HG'] - odds_and_results_df['VG']
odds_and_results_df['Away_y'] = odds_and_results_df['Away_y'].apply(lambda x: rename_dict[x])
odds_and_results_df = odds_and_results_df.dropna()
odds_and_results_df.shape
winning_team = []
for row in odds_and_results_df.iterrows():
    if row[1][10] < 0: 
        winning_team.append(row[1][5])
    elif row[1][10] > 0: 
        winning_team.append(row[1][4])
    else:
        print(row)
odds_and_results_df['Winner'] = winning_team
# odds_and_results_df.head()

# %%
odds_and_results_df = odds_and_results_df[['Date','Home','H_odd','Away_y','A_odd','HG','VG','OT','ATT','Winner']]
odds_and_results_df.columns = ['Date','Home','Home_line','Away','Away_line','H_Goals','A_Goals','End','ATT','Winner']
odds_and_results_df['Home_line'] = odds_and_results_df['Home_line'].apply(lambda x: int(x))
odds_and_results_df['Away_line'] = odds_and_results_df['Away_line'].apply(lambda x: int(x))
# odds_and_results_df.head()

# %%
home_returns = []
away_returns = []
count = 0
for row in odds_and_results_df.iterrows():
    if row[1][9] == row[1][1]:
        away_loss = 10
        away_returns.append(- away_loss)
        if row[1][2] > 0:
            wins = row[1][2]/10
            home_returns.append(round(wins,1))
        elif row[1][2] < 0:
            mult = (100/-(row[1][2]))
            wins = mult*10
            home_returns.append(round(wins,1))
            
    elif row[1][9] == row[1][3]:
        home_loss = -10
        home_returns.append(home_loss)
        if row[1][4] > 0:
            wins = row[1][4]/10
            away_returns.append(round(wins,1))
        elif row[1][4] < 0:
            mult = (100/-(row[1][4]))
            wins = mult*10
            away_returns.append(round(wins,1))
    else: print(row[1])
            

# len(away_returns), len(home_returns), odds_and_results_df.shape

# %%
odds_and_results_df['H_returns'] = home_returns
odds_and_results_df['A_returns'] = away_returns
odds_and_results_df['H_returns'] = odds_and_results_df['H_returns'].apply(lambda x: float(x))
odds_and_results_df['A_returns'] =odds_and_results_df['A_returns'].apply(lambda x: float(x))
# odds_and_results_df.head()

# %%
ml_df = odds_and_results_df[['Date','Home','Home_line','Away','Away_line','H_Goals','A_Goals','Winner']]
ml_df['Home']= ml_df['Home'].apply(lambda x: ML_dict[x])
ml_df['Away']= ml_df['Away'].apply(lambda x: ML_dict[x])
ml_df['Winner']= ml_df['Winner'].apply(lambda x: ML_dict[x])
ml_df['Date'] = ml_df['Date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))
ml_df['Date_month'] = ml_df['Date'].apply(lambda x: x.month)
ml_df['Date_day'] = ml_df['Date'].apply(lambda x: x.day)
ml_df['Date_year'] = ml_df['Date'].apply(lambda x: x.year)
ml_df['Date_DOW'] = ml_df['Date'].apply(lambda x: x.weekday())
ml_df['Winner_score'] = ml_df['H_Goals'] - ml_df['A_Goals']
# ml_df.head()
# Out:
# C:\Users\Ryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Ryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Ryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Ryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Ryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Ryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Ryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
home_win = []
for row in ml_df.iterrows():
    if row[1][-1] > 0:
        result = 1
        home_win.append(1)
    elif row[1][-1] < 0:
        results = 0
        home_win.append(results)
    else: print(row[1][-1])
ml_df['Home_win'] = home_win

line_spreads = []
for row in ml_df.iterrows():
    if row[1][2] < 0:
        home_line = -(row[1][2])
    else: home_line = row[1][2]
    if row[1][4] < 0:
        away_line = -(row[1][4])
    else: away_line = row[1][4]
    line_spread = home_line + away_line
    line_spreads.append(line_spread)
len(line_spreads)
ml_df['line_spread'] = line_spreads
ml_df.head()
# Out:
#         Date  Home  Home_line  Away  Away_line  H_Goals  A_Goals  Winner  \
# 0 2009-10-01     3       -135    30        115      1.0      4.0      30
# 1 2009-10-01     5       -135    28        115      5.0      3.0       5
# 2 2009-10-01     8        155    24       -175      5.0      2.0       8
# 3 2009-10-01    27       -130    16        110      3.0      4.0      16
# 4 2009-10-02     6       -120    22        100      0.0      2.0      22
#
#    Date_month  Date_day  Date_year  Date_DOW  Winner_score  Home_win  \
# 0          10         1       2009         3          -3.0         0
# 1          10         1       2009         3           2.0         1
# 2          10         1       2009         3           3.0         1
# 3          10         1       2009         3          -1.0         0
# 4          10         2       2009         4          -2.0         0
#
#    line_spread
# 0          250
# 1          250
# 2          330
# 3          240
# 4          220

# %%
X = ml_df[['Date_month','Date_year','Date_day','Home','Home_line','Away','Away_line']]
y = ml_df[['Home_win']]

# %%
def all_season_results(year):
    X_tester7 = X[(X.Date_year == year)&(X.Date_month < 6)]
    y_tester7 = ml_df[(ml_df.Date_year == year)&(ml_df.Date_month < 6)]
    y_tester7 = y_tester7[['Home_win']]
    X_tester8 = X[(X.Date_year == (year -1)) & (X.Date_month > 6)]
    y_tester8 = ml_df[(ml_df.Date_year == (year -1)) & (ml_df.Date_month > 6)]
    y_tester8 = y_tester8[['Home_win']]
    X_tester9 = pd.concat([X_tester7,X_tester8])
    y_tester9 = pd.concat([y_tester7,y_tester8])

    test_df = pd.concat([X_tester9,y_tester9], axis = 1)

    def season_results(team):
        season_total = 0
        home_df = test_df[(test_df.Home == team)]
        away_df = test_df[(test_df.Away == team)]
        home_away_df  = pd.concat([home_df,away_df])
        for row in home_away_df.iterrows():
            if row[1][7] == 1:
                if row[1][3] == team:
                    if row[1][4] > 0:
                        winning = row[1][4]*10
                    else: 
                        mult = 100/(-row[1][4])
                        winning = mult*1000
                    season_total += winning
                else:
                    loss = -1000
                    season_total += loss
            else:
                if row[1][5] == team:
                    if row[1][6] > 0:
                        winning = row[1][6]*10
                    else: 
                        mult = 100/(-row[1][6])
                        winning = mult*1000
                    season_total += winning
                else:
                    loss = -1000
                    season_total += loss
        return[num_to_team[team],season_total]
    dictionary_name = f"results_{year}"
    dictionary_name = {}
    return_list=[]
    for num in range(1,32):
        team,season_total = season_results(num)
        dictionary_name[team] = int(season_total)
#         return_list.append(dictionary_name)
    return(dictionary_name)

season_years = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]
all_season_results_dict = {}
for year in season_years:
    results = all_season_results(year)
    all_season_results_dict[f'{year}']=results

all_season_results_dict
# Out:
# {'2010': {'Anaheim Ducks': -1014,
#   'Arizona Coyotes': 4483,
#   'Boston Bruins': -11143,
#   'Buffalo Sabres': -3895,
#   'Calgary Flames': -4751,
#   'Carolina Hurricanes': -7690,
#   'Chicago Blackhawks': 4491,
#   'Colorado Avalanche': 4758,
#   'Columbus Blue Jackets': -17722,
#   'Dallas Stars': -6722,
#   'Detroit Red Wings': -1485,
#   'Edmonton Oilers': -14665,
#   'Florida Panthers': -8305,
#   'Los Angeles Kings': 7151,
#   'Minnesota Wild': 26,
#   'Montreal Canadiens': -2401,
#   'Nashville Predators': 10024,
#   'New Jersey Devils': 5361,
#   'New York Rangers': -8517,
#   'New York Islanders': -2901,
#   'Ottawa Senators': 6450,
#   'Philadelphia Flyers': -6025,
#   'Pittsburgh Penguins': -3326,
#   'San Jose Sharks': -634,
#   'St Louis Blues': 10680,
#   'Tampa Bay Lightning': -15407,
#   'Toronto Maple Leafs': -16664,
#   'Vancouver Canucks': 5963,
#   'Vegas Golden Knights': 0,
#   'Washington Capitals': 5616,
#   'Winnipeg Jets': -4688},
#  '2011': {'Anaheim Ducks': 12052,
#   'Arizona Coyotes': 8211,
#   'Boston Bruins': 2664,
#   'Buffalo Sabres': 120,
#   'Calgary Flames': -6133,
#   'Carolina Hurricanes': -9213,
#   'Chicago Blackhawks': -3932,
#   'Colorado Avalanche': -19610,
#   'Columbus Blue Jackets': -10029,
#   'Dallas Stars': 3187,
#   'Detroit Red Wings': -222,
#   'Edmonton Oilers': -20413,
#   'Florida Panthers': -17981,
#   'Los Angeles Kings': 2441,
#   'Minnesota Wild': -792,
#   'Montreal Canadiens': 5605,
#   'Nashville Predators': 6641,
#   'New Jersey Devils': -6075,
#   'New York Rangers': 4780,
#   'New York Islanders': -12454,
#   'Ottawa Senators': -10907,
#   'Philadelphia Flyers': 1619,
#   'Pittsburgh Penguins': 5360,
#   'San Jose Sharks': 368,
#   'St Louis Blues': -5638,
#   'Tampa Bay Lightning': 3812,
#   'Toronto Maple Leafs': -5790,
#   'Vancouver Canucks': 4668,
#   'Vegas Golden Knights': 0,
#   'Washington Capitals': 557,
#   'Winnipeg Jets': 883},
#  '2012': {'Anaheim Ducks': -11566,
#   'Arizona Coyotes': 1919,
#   'Boston Bruins': -1636,
#   'Buffalo Sabres': -6393,
#   'Calgary Flames': -6693,
#   'Carolina Hurricanes': -9274,
#   'Chicago Blackhawks': -1282,
#   'Colorado Avalanche': 9142,
#   'Columbus Blue Jackets': -13474,
#   'Dallas Stars': 2394,
#   'Detroit Red Wings': -1486,
#   'Edmonton Oilers': -5744,
#   'Florida Panthers': -5096,
#   'Los Angeles Kings': -6410,
#   'Minnesota Wild': -8119,
#   'Montreal Canadiens': -18304,
#   'Nashville Predators': 3226,
#   'New Jersey Devils': 13343,
#   'New York Rangers': 8502,
#   'New York Islanders': -3428,
#   'Ottawa Senators': 3606,
#   'Philadelphia Flyers': 473,
#   'Pittsburgh Penguins': 4457,
#   'San Jose Sharks': -2306,
#   'St Louis Blues': -4844,
#   'Tampa Bay Lightning': -3496,
#   'Toronto Maple Leafs': -13489,
#   'Vancouver Canucks': 4543,
#   'Vegas Golden Knights': 0,
#   'Washington Capitals': -5864,
#   'Winnipeg Jets': -4204},
#  '2013': {'Anaheim Ducks': 10973,
#   'Arizona Coyotes': -5347,
#   'Boston Bruins': -3001,
#   'Buffalo Sabres': -2222,
#   'Calgary Flames': -5544,
#   'Carolina Hurricanes': -9155,
#   'Chicago Blackhawks': 10398,
#   'Colorado Avalanche': -13850,
#   'Columbus Blue Jackets': 8049,
#   'Dallas Stars': 2412,
#   'Detroit Red Wings': -2654,
#   'Edmonton Oilers': -9853,
#   'Florida Panthers': -13398,
#   'Los Angeles Kings': -3289,
#   'Minnesota Wild': 1992,
#   'Montreal Canadiens': 6436,
#   'Nashville Predators': -17398,
#   'New Jersey Devils': -12689,
#   'New York Rangers': -2696,
#   'New York Islanders': 1374,
#   'Ottawa Senators': 1847,
#   'Philadelphia Flyers': -2886,
#   'Pittsburgh Penguins': 12925,
#   'San Jose Sharks': -3543,
#   'St Louis Blues': 2334,
#   'Tampa Bay Lightning': -14468,
#   'Toronto Maple Leafs': 3934,
#   'Vancouver Canucks': -3592,
#   'Vegas Golden Knights': 0,
#   'Washington Capitals': 4461,
#   'Winnipeg Jets': -727},
#  '2014': {'Anaheim Ducks': 7832,
#   'Arizona Coyotes': -8605,
#   'Boston Bruins': 7452,
#   'Buffalo Sabres': -30165,
#   'Calgary Flames': 2193,
#   'Carolina Hurricanes': -5587,
#   'Chicago Blackhawks': -4119,
#   'Colorado Avalanche': 13788,
#   'Columbus Blue Jackets': -136,
#   'Dallas Stars': -3424,
#   'Detroit Red Wings': -6168,
#   'Edmonton Oilers': -17312,
#   'Florida Panthers': -14280,
#   'Los Angeles Kings': 1036,
#   'Minnesota Wild': -206,
#   'Montreal Canadiens': 5272,
#   'Nashville Predators': 4285,
#   'New Jersey Devils': -9205,
#   'New York Rangers': 4721,
#   'New York Islanders': -3289,
#   'Ottawa Senators': -10302,
#   'Philadelphia Flyers': 1658,
#   'Pittsburgh Penguins': 4589,
#   'San Jose Sharks': -634,
#   'St Louis Blues': 385,
#   'Tampa Bay Lightning': 6058,
#   'Toronto Maple Leafs': -7029,
#   'Vancouver Canucks': -13874,
#   'Vegas Golden Knights': 0,
#   'Washington Capitals': -8994,
#   'Winnipeg Jets': -2105},
#  '2015': {'Anaheim Ducks': 9781,
#   'Arizona Coyotes': -24203,
#   'Boston Bruins': -8878,
#   'Buffalo Sabres': -13270,
#   'Calgary Flames': 11614,
#   'Carolina Hurricanes': -15498,
#   'Chicago Blackhawks': -1803,
#   'Colorado Avalanche': 901,
#   'Columbus Blue Jackets': 9602,
#   'Dallas Stars': -198,
#   'Detroit Red Wings': -5921,
#   'Edmonton Oilers': -19948,
#   'Florida Panthers': -1130,
#   'Los Angeles Kings': -13071,
#   'Minnesota Wild': 1618,
#   'Montreal Canadiens': 6336,
#   'Nashville Predators': 1857,
#   'New Jersey Devils': -17784,
#   'New York Rangers': 11204,
#   'New York Islanders': 5021,
#   'Ottawa Senators': 3413,
#   'Philadelphia Flyers': -12839,
#   'Pittsburgh Penguins': -11883,
#   'San Jose Sharks': -6668,
#   'St Louis Blues': 2813,
#   'Tampa Bay Lightning': 2620,
#   'Toronto Maple Leafs': -18481,
#   'Vancouver Canucks': 6465,
#   'Vegas Golden Knights': 0,
#   'Washington Capitals': 3124,
#   'Winnipeg Jets': 4516},
#  '2016': {'Anaheim Ducks': 985,
#   'Arizona Coyotes': -1895,
#   'Boston Bruins': -4533,
#   'Buffalo Sabres': 1274,
#   'Calgary Flames': -6645,
#   'Carolina Hurricanes': -8433,
#   'Chicago Blackhawks': -1965,
#   'Colorado Avalanche': 3023,
#   'Columbus Blue Jackets': -8468,
#   'Dallas Stars': 9670,
#   'Detroit Red Wings': -6053,
#   'Edmonton Oilers': -14430,
#   'Florida Panthers': 4064,
#   'Los Angeles Kings': -87,
#   'Minnesota Wild': -11802,
#   'Montreal Canadiens': -7677,
#   'Nashville Predators': -7564,
#   'New Jersey Devils': 465,
#   'New York Rangers': -1825,
#   'New York Islanders': -1291,
#   'Ottawa Senators': -6118,
#   'Philadelphia Flyers': 1261,
#   'Pittsburgh Penguins': 4970,
#   'San Jose Sharks': 743,
#   'St Louis Blues': 7635,
#   'Tampa Bay Lightning': -3415,
#   'Toronto Maple Leafs': -13961,
#   'Vancouver Canucks': -13117,
#   'Vegas Golden Knights': 0,
#   'Washington Capitals': 10364,
#   'Winnipeg Jets': -10032},
#  '2017': {'Anaheim Ducks': 1034,
#   'Arizona Coyotes': -4856,
#   'Boston Bruins': -4649,
#   'Buffalo Sabres': -8112,
#   'Calgary Flames': 2930,
#   'Carolina Hurricanes': -8834,
#   'Chicago Blackhawks': 5510,
#   'Colorado Avalanche': -27157,
#   'Columbus Blue Jackets': 10406,
#   'Dallas Stars': -13816,
#   'Detroit Red Wings': -11306,
#   'Edmonton Oilers': 2394,
#   'Florida Panthers': -12989,
#   'Los Angeles Kings': -10217,
#   'Minnesota Wild': 7316,
#   'Montreal Canadiens': 2920,
#   'Nashville Predators': -6069,
#   'New Jersey Devils': -22134,
#   'New York Rangers': 6523,
#   'New York Islanders': 1815,
#   'Ottawa Senators': 7476,
#   'Philadelphia Flyers': -4524,
#   'Pittsburgh Penguins': -515,
#   'San Jose Sharks': -1665,
#   'St Louis Blues': 3973,
#   'Tampa Bay Lightning': -3833,
#   'Toronto Maple Leafs': -4229,
#   'Vancouver Canucks': -12444,
#   'Vegas Golden Knights': 0,
#   'Washington Capitals': 6921,
#   'Winnipeg Jets': -5473},
#  '2018': {'Anaheim Ducks': -2438,
#   'Arizona Coyotes': -14737,
#   'Boston Bruins': 5542,
#   'Buffalo Sabres': -18266,
#   'Calgary Flames': -8894,
#   'Carolina Hurricanes': -11178,
#   'Chicago Blackhawks': -17925,
#   'Colorado Avalanche': 7995,
#   'Columbus Blue Jackets': -1054,
#   'Dallas Stars': -3408,
#   'Detroit Red Wings': -16155,
#   'Edmonton Oilers': -10296,
#   'Florida Panthers': 1882,
#   'Los Angeles Kings': 685,
#   'Minnesota Wild': -43,
#   'Montreal Canadiens': -25525,
#   'Nashville Predators': 8869,
#   'New Jersey Devils': 11206,
#   'New York Rangers': -14178,
#   'New York Islanders': -13867,
#   'Ottawa Senators': -17092,
#   'Philadelphia Flyers': -1878,
#   'Pittsburgh Penguins': -3176,
#   'San Jose Sharks': -901,
#   'St Louis Blues': -717,
#   'Tampa Bay Lightning': 6143,
#   'Toronto Maple Leafs': 5992,
#   'Vancouver Canucks': -6536,
#   'Vegas Golden Knights': 17370,
#   'Washington Capitals': 3449,
#   'Winnipeg Jets': 10409},
#  '2019': {'Anaheim Ducks': -6864,
#   'Arizona Coyotes': 1881,
#   'Boston Bruins': 2610,
#   'Buffalo Sabres': -12463,
#   'Calgary Flames': 5033,
#   'Carolina Hurricanes': 3117,
#   'Chicago Blackhawks': -4575,
#   'Colorado Avalanche': -8214,
#   'Columbus Blue Jackets': -498,
#   'Dallas Stars': -2925,
#   'Detroit Red Wings': -1888,
#   'Edmonton Oilers': -11750,
#   'Florida Panthers': -9342,
#   'Los Angeles Kings': -14065,
#   'Minnesota Wild': -11858,
#   'Montreal Canadiens': 3945,
#   'Nashville Predators': 128,
#   'New Jersey Devils': -15618,
#   'New York Rangers': -9403,
#   'New York Islanders': 12676,
#   'Ottawa Senators': -8583,
#   'Philadelphia Flyers': -8160,
#   'Pittsburgh Penguins': -6328,
#   'San Jose Sharks': -3114,
#   'St Louis Blues': 4671,
#   'Tampa Bay Lightning': 18130,
#   'Toronto Maple Leafs': -2444,
#   'Vancouver Canucks': -3180,
#   'Vegas Golden Knights': -7480,
#   'Washington Capitals': 1945,
#   'Winnipeg Jets': -3801}}

# %%
all_season_results_df = pd.DataFrame.from_records(all_season_results_dict)
all_season_results_df=all_season_results_df.reset_index()
all_season_results_df.columns = ['Team','2010_results','2011_results','2012_results','2013_results','2014_results','2015_results','2016_results','2017_results','2018_results','2019_results','ff']
all_season_results_df = all_season_results_df[['Team','2010_results','2011_results','2012_results','2013_results','2014_results','2015_results','2016_results','2017_results','2018_results','2019_results']]
all_season_results_df['sum'] = (all_season_results_df['2010_results']+all_season_results_df['2011_results']+all_season_results_df['2012_results']+all_season_results_df['2013_results']+all_season_results_df['2014_results']+all_season_results_df['2015_results']+all_season_results_df['2016_results']+all_season_results_df['2017_results']+all_season_results_df['2018_results']+all_season_results_df['2019_results'])

all_season_results_df
# Out:
#                      Team  2010_results  2011_results  2012_results  \
# 0           Anaheim Ducks  -1014.542563  12052.577410 -11566.477159
# 1         Arizona Coyotes   4483.164983   8211.400081   1919.047619
# 2           Boston Bruins -11143.228278   2664.940196  -1636.383647
# 3          Buffalo Sabres  -3895.884539    120.396090  -6393.468312
# 4          Calgary Flames  -4751.819145  -6133.180902  -6693.712837
# 5     Carolina Hurricanes  -7690.347525  -9213.164767  -9274.863706
# 6      Chicago Blackhawks   4491.094687  -3932.108399  -1282.373588
# 7      Colorado Avalanche   4758.837272 -19610.762016   9142.307118
# 8   Columbus Blue Jackets -17722.878610 -10029.917509 -13474.410774
# 9            Dallas Stars  -6722.818141   3187.678963   2394.286561
# 10      Detroit Red Wings  -1485.520653   -222.310220  -1486.862855
# 11        Edmonton Oilers -14665.866713 -20413.539794  -5744.620767
# 12       Florida Panthers  -8305.683410 -17981.508513  -5096.569108
# 13      Los Angeles Kings   7151.984843   2441.488637  -6410.721734
# 14         Minnesota Wild     26.833645   -792.915382  -8119.284841
# 15     Montreal Canadiens  -2401.927749   5605.592800 -18304.286276
# 16    Nashville Predators  10024.169216   6641.854846   3226.719114
# 17      New Jersey Devils   5361.783654  -6075.320656  13343.017792
# 18     New York Islanders  -2901.990239 -12454.720497  -3428.292313
# 19       New York Rangers  -8517.765008   4780.966987   8502.769567
# 20        Ottawa Senators   6450.238109 -10907.241892   3606.122500
# 21    Philadelphia Flyers  -6025.632960   1619.488262    473.785529
# 22    Pittsburgh Penguins  -3326.261212   5360.603460   4457.291271
# 23        San Jose Sharks   -634.817586    368.212651  -2306.166969
# 24         St Louis Blues  10680.712251  -5638.528139  -4844.359747
# 25    Tampa Bay Lightning -15407.804794   3812.764789  -3496.858890
# 26    Toronto Maple Leafs -16664.160228  -5790.000966 -13489.587279
# 27      Vancouver Canucks   5963.415812   4668.369654   4543.658820
# 28   Vegas Golden Knights      0.000000      0.000000      0.000000
# 29    Washington Capitals   5616.217332    557.177214  -5864.146682
# 30          Winnipeg Jets  -4688.528139    883.850932  -4204.310031
#
#     2013_results  2014_results  2015_results  2016_results  2017_results  \
# 0   10973.470924   7832.319783   9781.030373    985.007467   1034.317737
# 1   -5347.619048  -8605.194805 -24203.454900  -1895.645102  -4856.448724
# 2   -3001.527194   7452.596440  -8878.510815  -4533.765988  -4649.484768
# 3   -2222.591177 -30165.238095 -13270.000000   1274.670112  -8112.760573
# 4   -5544.955447   2193.570844  11614.135651  -6645.447489   2930.393650
# 5   -9155.333122  -5587.253388 -15498.177359  -8433.986014  -8834.732664
# 6   10398.318731  -4119.706391  -1803.173043  -1965.093837   5510.854803
# 7  -13850.544477  13788.160672    901.767113   3023.967073 -27157.532468
# 8    8049.670619   -136.462822   9602.892310  -8468.700253  10406.188227
# 9    2412.350210  -3424.724403   -198.275095   9670.648002 -13816.966769
# 10  -2654.555842  -6168.438671  -5921.076101  -6053.508825 -11306.708233
# 11  -9853.701471 -17312.793075 -19948.383838 -14430.404060   2394.305749
# 12 -13398.484848 -14280.151515  -1130.065234   4064.691806 -12989.984601
# 13  -3289.037715   1036.036207 -13071.399842    -87.329146 -10217.169622
# 14   1992.466603   -206.826938   1618.039136 -11802.351623   7316.654122
# 15   6436.019027   5272.641647   6336.208452  -7677.794621   2920.273383
# 16 -17398.118548   4285.154439   1857.180274  -7564.185893  -6069.583535
# 17 -12689.806977  -9205.902082 -17784.267503    465.199213 -22134.075290
# 18   1374.403757  -3289.678872   5021.261269  -1291.347479   1815.624563
# 19  -2696.673786   4721.632845  11204.812756  -1825.513932   6523.113025
# 20   1847.897404 -10302.273874   3413.428529  -6118.889465   7476.277835
# 21  -2886.572736   1658.923783 -12839.405325   1261.799805  -4524.453927
# 22  12925.282135   4589.045981 -11883.413599   4970.332056   -515.847207
# 23  -3543.037611   -634.771524  -6668.660447    743.014414  -1665.501562
# 24   2334.357288    385.724203   2813.676088   7635.803209   3973.559212
# 25 -14468.149604   6058.049255   2620.787483  -3415.827539  -3833.857399
# 26   3934.708005  -7029.498806 -18481.898355 -13961.076025  -4229.575833
# 27  -3592.401285 -13874.773982   6465.117586 -13117.026524 -12444.526494
# 28      0.000000      0.000000      0.000000      0.000000      0.000000
# 29   4461.904167  -8994.828774   3124.050948  10364.799481   6921.371542
# 30   -727.131817  -2105.428067   4516.583143 -10032.531339  -5473.459925
#
#     2018_results  2019_results            sum
# 0   -2438.703868  -6864.454276   20774.545828
# 1  -14737.313089   1881.599912  -43150.463072
# 2    5542.519353   2610.022743  -15572.821959
# 3  -18266.926796 -12463.616294  -93395.419584
# 4   -8894.302041   5033.075588  -16892.242128
# 5  -11178.141478   3117.800675  -81748.199348
# 6  -17925.851966  -4575.544773  -15203.583778
# 7    7995.661436  -8214.629402  -29222.767678
# 8   -1054.512500   -498.781112  -23326.912425
# 9   -3408.649689  -2925.277201  -12831.747562
# 10 -16155.181887  -1888.004237  -53342.167526
# 11 -10296.526193 -11750.263502 -122021.793663
# 12   1882.775038  -9342.848305  -76577.828691
# 13    685.447741 -14065.884518  -35826.585150
# 14    -43.691403 -11858.481898  -21869.558579
# 15 -25525.931659   3945.309373  -23393.895622
# 16   8869.128453    128.335390    4000.653757
# 17  11206.759790 -15618.437858  -53131.049917
# 18 -13867.235561  12676.078602  -16345.896770
# 19 -14178.382693  -9403.260167    -888.300406
# 20 -17092.195264  -8583.225693  -30209.861810
# 21  -1878.667543  -8160.976246  -31301.711357
# 22  -3176.658992  -6328.171718    7072.202176
# 23   -901.777747  -3114.964475  -18358.470857
# 24   -717.994073   4671.367422   21294.317715
# 25   6143.020785  18130.318385   -3857.557530
# 26   5992.221129  -2444.892992  -72163.761349
# 27  -6536.019198  -3180.138944  -31104.324556
# 28  17370.906849  -7480.908739    9889.998110
# 29   3449.948660   1945.482547   21581.976434
# 30  10409.294278  -3801.328785  -15222.989749

# %%
all_standings=[]
for num in range(2010,2020):
    standings_df_2010 = pd.read_html(f'https://www.hockey-reference.com/leagues/NHL_{num}_standings.html')[2]
    all_standings.append(standings_df_2010)
    
all_standings_dict = {}
for num in range(0,10):
    all_standings_dict[num] = all_standings[num][['Rk','Unnamed: 1']].T.to_dict()
all_standings_dict
# Out:
# {0: {0: {'Rk': 1, 'Unnamed: 1': 'Washington Capitals'},
#   1: {'Rk': 2, 'Unnamed: 1': 'San Jose Sharks'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Chicago Blackhawks'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Phoenix Coyotes'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Vancouver Canucks'},
#   5: {'Rk': 6, 'Unnamed: 1': 'New Jersey Devils'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Detroit Red Wings'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   8: {'Rk': 9, 'Unnamed: 1': 'Los Angeles Kings'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Nashville Predators'},
#   10: {'Rk': 11, 'Unnamed: 1': 'Buffalo Sabres'},
#   11: {'Rk': 12, 'Unnamed: 1': 'Colorado Avalanche'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Ottawa Senators'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Boston Bruins'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Calgary Flames'},
#   15: {'Rk': 16, 'Unnamed: 1': 'St. Louis Blues'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Anaheim Ducks'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Philadelphia Flyers'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Montreal Canadiens'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Dallas Stars'},
#   20: {'Rk': 21, 'Unnamed: 1': 'New York Rangers'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Minnesota Wild'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Atlanta Thrashers'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Carolina Hurricanes'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   25: {'Rk': 26, 'Unnamed: 1': 'New York Islanders'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Florida Panthers'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Edmonton Oilers'}},
#  1: {0: {'Rk': 1, 'Unnamed: 1': 'Vancouver Canucks'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Washington Capitals'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Philadelphia Flyers'},
#   4: {'Rk': 5, 'Unnamed: 1': 'San Jose Sharks'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Detroit Red Wings'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Boston Bruins'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   8: {'Rk': 9, 'Unnamed: 1': 'Anaheim Ducks'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Nashville Predators'},
#   10: {'Rk': 11, 'Unnamed: 1': 'Phoenix Coyotes'},
#   11: {'Rk': 12, 'Unnamed: 1': 'Los Angeles Kings'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Chicago Blackhawks'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Montreal Canadiens'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Buffalo Sabres'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Dallas Stars'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Calgary Flames'},
#   17: {'Rk': 18, 'Unnamed: 1': 'New York Rangers'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Carolina Hurricanes'},
#   19: {'Rk': 20, 'Unnamed: 1': 'St. Louis Blues'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Minnesota Wild'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   22: {'Rk': 23, 'Unnamed: 1': 'New Jersey Devils'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Atlanta Thrashers'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Ottawa Senators'},
#   26: {'Rk': 27, 'Unnamed: 1': 'New York Islanders'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Florida Panthers'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Colorado Avalanche'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Edmonton Oilers'}},
#  2: {0: {'Rk': 1, 'Unnamed: 1': 'Vancouver Canucks'},
#   1: {'Rk': 2, 'Unnamed: 1': 'New York Rangers'},
#   2: {'Rk': 3, 'Unnamed: 1': 'St. Louis Blues'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Nashville Predators'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Philadelphia Flyers'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Boston Bruins'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Detroit Red Wings'},
#   8: {'Rk': 9, 'Unnamed: 1': 'New Jersey Devils'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Chicago Blackhawks'},
#   10: {'Rk': 11, 'Unnamed: 1': 'Phoenix Coyotes'},
#   11: {'Rk': 12, 'Unnamed: 1': 'San Jose Sharks'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Los Angeles Kings'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Florida Panthers'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Washington Capitals'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Ottawa Senators'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Calgary Flames'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Dallas Stars'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Buffalo Sabres'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Colorado Avalanche'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Winnipeg Jets'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Carolina Hurricanes'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Minnesota Wild'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Anaheim Ducks'},
#   26: {'Rk': 27, 'Unnamed: 1': 'New York Islanders'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Montreal Canadiens'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Edmonton Oilers'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Columbus Blue Jackets'}},
#  3: {0: {'Rk': 1, 'Unnamed: 1': 'Chicago Blackhawks'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Anaheim Ducks'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Montreal Canadiens'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Boston Bruins'},
#   5: {'Rk': 6, 'Unnamed: 1': 'St. Louis Blues'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Los Angeles Kings'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Vancouver Canucks'},
#   8: {'Rk': 9, 'Unnamed: 1': 'Washington Capitals'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   10: {'Rk': 11, 'Unnamed: 1': 'San Jose Sharks'},
#   11: {'Rk': 12, 'Unnamed: 1': 'New York Rangers'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Ottawa Senators'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Detroit Red Wings'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Minnesota Wild'},
#   15: {'Rk': 16, 'Unnamed: 1': 'New York Islanders'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Winnipeg Jets'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Phoenix Coyotes'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Philadelphia Flyers'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Dallas Stars'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Buffalo Sabres'},
#   22: {'Rk': 23, 'Unnamed: 1': 'New Jersey Devils'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Edmonton Oilers'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Calgary Flames'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Carolina Hurricanes'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Nashville Predators'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Colorado Avalanche'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Florida Panthers'}},
#  4: {0: {'Rk': 1, 'Unnamed: 1': 'Boston Bruins'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Anaheim Ducks'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Colorado Avalanche'},
#   3: {'Rk': 4, 'Unnamed: 1': 'St. Louis Blues'},
#   4: {'Rk': 5, 'Unnamed: 1': 'San Jose Sharks'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Chicago Blackhawks'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   8: {'Rk': 9, 'Unnamed: 1': 'Los Angeles Kings'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Montreal Canadiens'},
#   10: {'Rk': 11, 'Unnamed: 1': 'Minnesota Wild'},
#   11: {'Rk': 12, 'Unnamed: 1': 'New York Rangers'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Philadelphia Flyers'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Detroit Red Wings'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Dallas Stars'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Washington Capitals'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Phoenix Coyotes'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Nashville Predators'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Ottawa Senators'},
#   20: {'Rk': 21, 'Unnamed: 1': 'New Jersey Devils'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Winnipeg Jets'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Carolina Hurricanes'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Vancouver Canucks'},
#   25: {'Rk': 26, 'Unnamed: 1': 'New York Islanders'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Calgary Flames'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Edmonton Oilers'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Florida Panthers'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Buffalo Sabres'}},
#  5: {0: {'Rk': 1, 'Unnamed: 1': 'New York Rangers'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Montreal Canadiens'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Anaheim Ducks'},
#   3: {'Rk': 4, 'Unnamed: 1': 'St. Louis Blues'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Nashville Predators'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Chicago Blackhawks'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Vancouver Canucks'},
#   8: {'Rk': 9, 'Unnamed: 1': 'New York Islanders'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Washington Capitals'},
#   10: {'Rk': 11, 'Unnamed: 1': 'Minnesota Wild'},
#   11: {'Rk': 12, 'Unnamed: 1': 'Detroit Red Wings'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Ottawa Senators'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Winnipeg Jets'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Calgary Flames'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Boston Bruins'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Los Angeles Kings'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Dallas Stars'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Florida Panthers'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Colorado Avalanche'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   22: {'Rk': 23, 'Unnamed: 1': 'San Jose Sharks'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Philadelphia Flyers'},
#   24: {'Rk': 25, 'Unnamed: 1': 'New Jersey Devils'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Carolina Hurricanes'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Edmonton Oilers'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Arizona Coyotes'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Buffalo Sabres'}},
#  6: {0: {'Rk': 1, 'Unnamed: 1': 'Washington Capitals'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Dallas Stars'},
#   2: {'Rk': 3, 'Unnamed: 1': 'St. Louis Blues'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Chicago Blackhawks'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Florida Panthers'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Anaheim Ducks'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Los Angeles Kings'},
#   8: {'Rk': 9, 'Unnamed: 1': 'New York Rangers'},
#   9: {'Rk': 10, 'Unnamed: 1': 'New York Islanders'},
#   10: {'Rk': 11, 'Unnamed: 1': 'San Jose Sharks'},
#   11: {'Rk': 12, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Nashville Predators'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Philadelphia Flyers'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Boston Bruins'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Detroit Red Wings'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Minnesota Wild'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Carolina Hurricanes'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Ottawa Senators'},
#   19: {'Rk': 20, 'Unnamed: 1': 'New Jersey Devils'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Colorado Avalanche'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Montreal Canadiens'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Buffalo Sabres'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Arizona Coyotes'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Winnipeg Jets'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Calgary Flames'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Vancouver Canucks'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Edmonton Oilers'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Toronto Maple Leafs'}},
#  7: {0: {'Rk': 1, 'Unnamed: 1': 'Washington Capitals'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Chicago Blackhawks'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Minnesota Wild'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Anaheim Ducks'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Edmonton Oilers'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Montreal Canadiens'},
#   8: {'Rk': 9, 'Unnamed: 1': 'New York Rangers'},
#   9: {'Rk': 10, 'Unnamed: 1': 'San Jose Sharks'},
#   10: {'Rk': 11, 'Unnamed: 1': 'St. Louis Blues'},
#   11: {'Rk': 12, 'Unnamed: 1': 'Ottawa Senators'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Boston Bruins'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Calgary Flames'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Nashville Predators'},
#   17: {'Rk': 18, 'Unnamed: 1': 'New York Islanders'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Philadelphia Flyers'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Winnipeg Jets'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Carolina Hurricanes'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Los Angeles Kings'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Florida Panthers'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Dallas Stars'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Detroit Red Wings'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Buffalo Sabres'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Arizona Coyotes'},
#   27: {'Rk': 28, 'Unnamed: 1': 'New Jersey Devils'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Vancouver Canucks'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Colorado Avalanche'}},
#  8: {0: {'Rk': 1, 'Unnamed: 1': 'Nashville Predators'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Winnipeg Jets'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Boston Bruins'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Vegas Golden Knights'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Washington Capitals'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Minnesota Wild'},
#   8: {'Rk': 9, 'Unnamed: 1': 'Anaheim Ducks'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   10: {'Rk': 11, 'Unnamed: 1': 'San Jose Sharks'},
#   11: {'Rk': 12, 'Unnamed: 1': 'Los Angeles Kings'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Philadelphia Flyers'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   14: {'Rk': 15, 'Unnamed: 1': 'New Jersey Devils'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Florida Panthers'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Colorado Avalanche'},
#   17: {'Rk': 18, 'Unnamed: 1': 'St. Louis Blues'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Dallas Stars'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Calgary Flames'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Carolina Hurricanes'},
#   21: {'Rk': 22, 'Unnamed: 1': 'New York Islanders'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Edmonton Oilers'},
#   23: {'Rk': 24, 'Unnamed: 1': 'New York Rangers'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Chicago Blackhawks'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Vancouver Canucks'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Detroit Red Wings'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Montreal Canadiens'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Arizona Coyotes'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Ottawa Senators'},
#   30: {'Rk': 31, 'Unnamed: 1': 'Buffalo Sabres'}},
#  9: {0: {'Rk': 1, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Calgary Flames'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Boston Bruins'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Washington Capitals'},
#   4: {'Rk': 5, 'Unnamed: 1': 'New York Islanders'},
#   5: {'Rk': 6, 'Unnamed: 1': 'San Jose Sharks'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Nashville Predators'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   8: {'Rk': 9, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Winnipeg Jets'},
#   10: {'Rk': 11, 'Unnamed: 1': 'Carolina Hurricanes'},
#   11: {'Rk': 12, 'Unnamed: 1': 'St. Louis Blues'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Montreal Canadiens'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Dallas Stars'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Vegas Golden Knights'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Colorado Avalanche'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Arizona Coyotes'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Florida Panthers'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Chicago Blackhawks'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Minnesota Wild'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Philadelphia Flyers'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Vancouver Canucks'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Anaheim Ducks'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Edmonton Oilers'},
#   25: {'Rk': 26, 'Unnamed: 1': 'New York Rangers'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Buffalo Sabres'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Detroit Red Wings'},
#   28: {'Rk': 29, 'Unnamed: 1': 'New Jersey Devils'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Los Angeles Kings'},
#   30: {'Rk': 31, 'Unnamed: 1': 'Ottawa Senators'}}}

# %%
for k,v in all_standings_dict.items():
    for z,x in v.items():
        x['Unnamed: 1'] = rename_dict[x['Unnamed: 1']]
all_standings_dict
# Out:
# {0: {0: {'Rk': 1, 'Unnamed: 1': 'Washington Capitals'},
#   1: {'Rk': 2, 'Unnamed: 1': 'San Jose Sharks'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Chicago Blackhawks'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Arizona Coyotes'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Vancouver Canucks'},
#   5: {'Rk': 6, 'Unnamed: 1': 'New Jersey Devils'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Detroit Red Wings'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   8: {'Rk': 9, 'Unnamed: 1': 'Los Angeles Kings'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Nashville Predators'},
#   10: {'Rk': 11, 'Unnamed: 1': 'Buffalo Sabres'},
#   11: {'Rk': 12, 'Unnamed: 1': 'Colorado Avalanche'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Ottawa Senators'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Boston Bruins'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Calgary Flames'},
#   15: {'Rk': 16, 'Unnamed: 1': 'St Louis Blues'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Anaheim Ducks'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Philadelphia Flyers'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Montreal Canadiens'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Dallas Stars'},
#   20: {'Rk': 21, 'Unnamed: 1': 'New York Rangers'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Minnesota Wild'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Winnipeg Jets'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Carolina Hurricanes'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   25: {'Rk': 26, 'Unnamed: 1': 'New York Islanders'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Florida Panthers'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Edmonton Oilers'}},
#  1: {0: {'Rk': 1, 'Unnamed: 1': 'Vancouver Canucks'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Washington Capitals'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Philadelphia Flyers'},
#   4: {'Rk': 5, 'Unnamed: 1': 'San Jose Sharks'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Detroit Red Wings'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Boston Bruins'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   8: {'Rk': 9, 'Unnamed: 1': 'Anaheim Ducks'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Nashville Predators'},
#   10: {'Rk': 11, 'Unnamed: 1': 'Arizona Coyotes'},
#   11: {'Rk': 12, 'Unnamed: 1': 'Los Angeles Kings'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Chicago Blackhawks'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Montreal Canadiens'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Buffalo Sabres'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Dallas Stars'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Calgary Flames'},
#   17: {'Rk': 18, 'Unnamed: 1': 'New York Rangers'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Carolina Hurricanes'},
#   19: {'Rk': 20, 'Unnamed: 1': 'St Louis Blues'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Minnesota Wild'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   22: {'Rk': 23, 'Unnamed: 1': 'New Jersey Devils'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Winnipeg Jets'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Ottawa Senators'},
#   26: {'Rk': 27, 'Unnamed: 1': 'New York Islanders'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Florida Panthers'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Colorado Avalanche'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Edmonton Oilers'}},
#  2: {0: {'Rk': 1, 'Unnamed: 1': 'Vancouver Canucks'},
#   1: {'Rk': 2, 'Unnamed: 1': 'New York Rangers'},
#   2: {'Rk': 3, 'Unnamed: 1': 'St Louis Blues'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Nashville Predators'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Philadelphia Flyers'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Boston Bruins'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Detroit Red Wings'},
#   8: {'Rk': 9, 'Unnamed: 1': 'New Jersey Devils'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Chicago Blackhawks'},
#   10: {'Rk': 11, 'Unnamed: 1': 'Arizona Coyotes'},
#   11: {'Rk': 12, 'Unnamed: 1': 'San Jose Sharks'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Los Angeles Kings'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Florida Panthers'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Washington Capitals'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Ottawa Senators'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Calgary Flames'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Dallas Stars'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Buffalo Sabres'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Colorado Avalanche'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Winnipeg Jets'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Carolina Hurricanes'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Minnesota Wild'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Anaheim Ducks'},
#   26: {'Rk': 27, 'Unnamed: 1': 'New York Islanders'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Montreal Canadiens'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Edmonton Oilers'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Columbus Blue Jackets'}},
#  3: {0: {'Rk': 1, 'Unnamed: 1': 'Chicago Blackhawks'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Anaheim Ducks'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Montreal Canadiens'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Boston Bruins'},
#   5: {'Rk': 6, 'Unnamed: 1': 'St Louis Blues'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Los Angeles Kings'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Vancouver Canucks'},
#   8: {'Rk': 9, 'Unnamed: 1': 'Washington Capitals'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   10: {'Rk': 11, 'Unnamed: 1': 'San Jose Sharks'},
#   11: {'Rk': 12, 'Unnamed: 1': 'New York Rangers'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Ottawa Senators'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Detroit Red Wings'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Minnesota Wild'},
#   15: {'Rk': 16, 'Unnamed: 1': 'New York Islanders'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Winnipeg Jets'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Arizona Coyotes'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Philadelphia Flyers'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Dallas Stars'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Buffalo Sabres'},
#   22: {'Rk': 23, 'Unnamed: 1': 'New Jersey Devils'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Edmonton Oilers'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Calgary Flames'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Carolina Hurricanes'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Nashville Predators'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Colorado Avalanche'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Florida Panthers'}},
#  4: {0: {'Rk': 1, 'Unnamed: 1': 'Boston Bruins'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Anaheim Ducks'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Colorado Avalanche'},
#   3: {'Rk': 4, 'Unnamed: 1': 'St Louis Blues'},
#   4: {'Rk': 5, 'Unnamed: 1': 'San Jose Sharks'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Chicago Blackhawks'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   8: {'Rk': 9, 'Unnamed: 1': 'Los Angeles Kings'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Montreal Canadiens'},
#   10: {'Rk': 11, 'Unnamed: 1': 'Minnesota Wild'},
#   11: {'Rk': 12, 'Unnamed: 1': 'New York Rangers'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Philadelphia Flyers'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Detroit Red Wings'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Dallas Stars'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Washington Capitals'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Arizona Coyotes'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Nashville Predators'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Ottawa Senators'},
#   20: {'Rk': 21, 'Unnamed: 1': 'New Jersey Devils'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Winnipeg Jets'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Carolina Hurricanes'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Vancouver Canucks'},
#   25: {'Rk': 26, 'Unnamed: 1': 'New York Islanders'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Calgary Flames'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Edmonton Oilers'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Florida Panthers'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Buffalo Sabres'}},
#  5: {0: {'Rk': 1, 'Unnamed: 1': 'New York Rangers'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Montreal Canadiens'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Anaheim Ducks'},
#   3: {'Rk': 4, 'Unnamed: 1': 'St Louis Blues'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Nashville Predators'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Chicago Blackhawks'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Vancouver Canucks'},
#   8: {'Rk': 9, 'Unnamed: 1': 'New York Islanders'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Washington Capitals'},
#   10: {'Rk': 11, 'Unnamed: 1': 'Minnesota Wild'},
#   11: {'Rk': 12, 'Unnamed: 1': 'Detroit Red Wings'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Ottawa Senators'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Winnipeg Jets'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Calgary Flames'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Boston Bruins'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Los Angeles Kings'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Dallas Stars'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Florida Panthers'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Colorado Avalanche'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   22: {'Rk': 23, 'Unnamed: 1': 'San Jose Sharks'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Philadelphia Flyers'},
#   24: {'Rk': 25, 'Unnamed: 1': 'New Jersey Devils'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Carolina Hurricanes'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Edmonton Oilers'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Arizona Coyotes'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Buffalo Sabres'}},
#  6: {0: {'Rk': 1, 'Unnamed: 1': 'Washington Capitals'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Dallas Stars'},
#   2: {'Rk': 3, 'Unnamed: 1': 'St Louis Blues'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Chicago Blackhawks'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Florida Panthers'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Anaheim Ducks'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Los Angeles Kings'},
#   8: {'Rk': 9, 'Unnamed: 1': 'New York Rangers'},
#   9: {'Rk': 10, 'Unnamed: 1': 'New York Islanders'},
#   10: {'Rk': 11, 'Unnamed: 1': 'San Jose Sharks'},
#   11: {'Rk': 12, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Nashville Predators'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Philadelphia Flyers'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Boston Bruins'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Detroit Red Wings'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Minnesota Wild'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Carolina Hurricanes'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Ottawa Senators'},
#   19: {'Rk': 20, 'Unnamed: 1': 'New Jersey Devils'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Colorado Avalanche'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Montreal Canadiens'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Buffalo Sabres'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Arizona Coyotes'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Winnipeg Jets'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Calgary Flames'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Vancouver Canucks'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Edmonton Oilers'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Toronto Maple Leafs'}},
#  7: {0: {'Rk': 1, 'Unnamed: 1': 'Washington Capitals'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Chicago Blackhawks'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Minnesota Wild'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Anaheim Ducks'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Edmonton Oilers'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Montreal Canadiens'},
#   8: {'Rk': 9, 'Unnamed: 1': 'New York Rangers'},
#   9: {'Rk': 10, 'Unnamed: 1': 'San Jose Sharks'},
#   10: {'Rk': 11, 'Unnamed: 1': 'St Louis Blues'},
#   11: {'Rk': 12, 'Unnamed: 1': 'Ottawa Senators'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Boston Bruins'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Calgary Flames'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Nashville Predators'},
#   17: {'Rk': 18, 'Unnamed: 1': 'New York Islanders'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Philadelphia Flyers'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Winnipeg Jets'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Carolina Hurricanes'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Los Angeles Kings'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Florida Panthers'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Dallas Stars'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Detroit Red Wings'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Buffalo Sabres'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Arizona Coyotes'},
#   27: {'Rk': 28, 'Unnamed: 1': 'New Jersey Devils'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Vancouver Canucks'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Colorado Avalanche'}},
#  8: {0: {'Rk': 1, 'Unnamed: 1': 'Nashville Predators'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Winnipeg Jets'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Boston Bruins'},
#   4: {'Rk': 5, 'Unnamed: 1': 'Vegas Golden Knights'},
#   5: {'Rk': 6, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Washington Capitals'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Minnesota Wild'},
#   8: {'Rk': 9, 'Unnamed: 1': 'Anaheim Ducks'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   10: {'Rk': 11, 'Unnamed: 1': 'San Jose Sharks'},
#   11: {'Rk': 12, 'Unnamed: 1': 'Los Angeles Kings'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Philadelphia Flyers'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   14: {'Rk': 15, 'Unnamed: 1': 'New Jersey Devils'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Florida Panthers'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Colorado Avalanche'},
#   17: {'Rk': 18, 'Unnamed: 1': 'St Louis Blues'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Dallas Stars'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Calgary Flames'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Carolina Hurricanes'},
#   21: {'Rk': 22, 'Unnamed: 1': 'New York Islanders'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Edmonton Oilers'},
#   23: {'Rk': 24, 'Unnamed: 1': 'New York Rangers'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Chicago Blackhawks'},
#   25: {'Rk': 26, 'Unnamed: 1': 'Vancouver Canucks'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Detroit Red Wings'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Montreal Canadiens'},
#   28: {'Rk': 29, 'Unnamed: 1': 'Arizona Coyotes'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Ottawa Senators'},
#   30: {'Rk': 31, 'Unnamed: 1': 'Buffalo Sabres'}},
#  9: {0: {'Rk': 1, 'Unnamed: 1': 'Tampa Bay Lightning'},
#   1: {'Rk': 2, 'Unnamed: 1': 'Calgary Flames'},
#   2: {'Rk': 3, 'Unnamed: 1': 'Boston Bruins'},
#   3: {'Rk': 4, 'Unnamed: 1': 'Washington Capitals'},
#   4: {'Rk': 5, 'Unnamed: 1': 'New York Islanders'},
#   5: {'Rk': 6, 'Unnamed: 1': 'San Jose Sharks'},
#   6: {'Rk': 7, 'Unnamed: 1': 'Nashville Predators'},
#   7: {'Rk': 8, 'Unnamed: 1': 'Toronto Maple Leafs'},
#   8: {'Rk': 9, 'Unnamed: 1': 'Pittsburgh Penguins'},
#   9: {'Rk': 10, 'Unnamed: 1': 'Winnipeg Jets'},
#   10: {'Rk': 11, 'Unnamed: 1': 'Carolina Hurricanes'},
#   11: {'Rk': 12, 'Unnamed: 1': 'St Louis Blues'},
#   12: {'Rk': 13, 'Unnamed: 1': 'Columbus Blue Jackets'},
#   13: {'Rk': 14, 'Unnamed: 1': 'Montreal Canadiens'},
#   14: {'Rk': 15, 'Unnamed: 1': 'Dallas Stars'},
#   15: {'Rk': 16, 'Unnamed: 1': 'Vegas Golden Knights'},
#   16: {'Rk': 17, 'Unnamed: 1': 'Colorado Avalanche'},
#   17: {'Rk': 18, 'Unnamed: 1': 'Arizona Coyotes'},
#   18: {'Rk': 19, 'Unnamed: 1': 'Florida Panthers'},
#   19: {'Rk': 20, 'Unnamed: 1': 'Chicago Blackhawks'},
#   20: {'Rk': 21, 'Unnamed: 1': 'Minnesota Wild'},
#   21: {'Rk': 22, 'Unnamed: 1': 'Philadelphia Flyers'},
#   22: {'Rk': 23, 'Unnamed: 1': 'Vancouver Canucks'},
#   23: {'Rk': 24, 'Unnamed: 1': 'Anaheim Ducks'},
#   24: {'Rk': 25, 'Unnamed: 1': 'Edmonton Oilers'},
#   25: {'Rk': 26, 'Unnamed: 1': 'New York Rangers'},
#   26: {'Rk': 27, 'Unnamed: 1': 'Buffalo Sabres'},
#   27: {'Rk': 28, 'Unnamed: 1': 'Detroit Red Wings'},
#   28: {'Rk': 29, 'Unnamed: 1': 'New Jersey Devils'},
#   29: {'Rk': 30, 'Unnamed: 1': 'Los Angeles Kings'},
#   30: {'Rk': 31, 'Unnamed: 1': 'Ottawa Senators'}}}

# %%
results_and_standing_dict = all_season_results_df[['Team','2010_results','2011_results','2012_results','2013_results','2014_results','2015_results','2016_results','2017_results','2018_results','2019_results']].set_index('Team').T.to_dict('dict')

# %%
# results_and_standing_dict
for team,v in results_and_standing_dict.items():
    for year,h in v.items():
        year_split = (year.split('_')[0].split('01')[1])
        for d,f in all_standings_dict.items():
            if int(year_split) == d:
                for s,r in f.items():
                    rank = f[s]['Rk']
                    if f[s]['Unnamed: 1'] == team:
                        v[year] = [v[year],rank]
                    elif f[s]['Unnamed: 1'] == 'Phoenix Coyotes':
                        if team == 'Arizona Coyotes':
                            v[year] = [v[year],rank]
                    elif f[s]['Unnamed: 1'] == 'Atlanta Thrashers':
                        if team == 'Winnipeg Jets':
                            v[year] = [v[year],rank]

                    
results_and_standing_dict['St Louis Blues']
# Out:
# {'2010_results': [10680.712250712251, 16],
#  '2011_results': [-5638.528138528139, 20],
#  '2012_results': [-4844.35974653366, 3],
#  '2013_results': [2334.3572880657275, 6],
#  '2014_results': [385.724203303232, 4],
#  '2015_results': [2813.676087764824, 4],
#  '2016_results': [7635.803208629295, 3],
#  '2017_results': [3973.5592122001863, 11],
#  '2018_results': [-717.9940728327823, 18],
#  '2019_results': [4671.367422289856, 12]}

# %%
list_of_2010 = []
list_of_2011 = []
list_of_2012 = []
list_of_2013 = []
list_of_2014 = []
list_of_2015 = []
list_of_2016 = []
list_of_2017 = []
list_of_2018 = []
list_of_2019 = []
for row in all_season_results_df.iterrows():
    list_of_2010.append(row[1][1])
    list_of_2011.append(row[1][2])
    list_of_2012.append(row[1][3])
    list_of_2013.append(row[1][4])
    list_of_2014.append(row[1][5])
    list_of_2015.append(row[1][6])
    list_of_2016.append(row[1][7])
    list_of_2017.append(row[1][8])
    list_of_2018.append(row[1][9])
    list_of_2019.append(row[1][10])
    
list_of_2010.sort(reverse=True)
list_of_2011.sort(reverse=True)
list_of_2012.sort(reverse=True)
list_of_2013.sort(reverse=True)
list_of_2014.sort(reverse=True)
list_of_2015.sort(reverse=True)
list_of_2016.sort(reverse=True)
list_of_2017.sort(reverse=True)
list_of_2018.sort(reverse=True)
list_of_2019.sort(reverse=True)

# %%
for k,v in results_and_standing_dict.items():
    for g,h in v.items():
        if g == '2010_results':
            if type(h) == list:
                for t,y in enumerate(list_of_2010):
                    if h[0] == y:
                        v[g] = {'result':h[0],'standings':h[1],'result_rank':t+1}
        if g == '2011_results':
            if type(h) == list:
                for t,y in enumerate(list_of_2011):
                    if h[0] == y:
                        v[g] = {'result':h[0],'standings':h[1],'result_rank':t+1}
        if g == '2012_results':
            if type(h) == list:
                for t,y in enumerate(list_of_2012):
                    if h[0] == y:
                        v[g] = {'result':h[0],'standings':h[1],'result_rank':t+1}
        if g == '2013_results':
            if type(h) == list:
                for t,y in enumerate(list_of_2013):
                    if h[0] == y:
                        v[g] = {'result':h[0],'standings':h[1],'result_rank':t+1}
        if g == '2014_results':
            if type(h) == list:
                for t,y in enumerate(list_of_2014):
                    if h[0] == y:
                        v[g] = {'result':h[0],'standings':h[1],'result_rank':t+1}
        if g == '2015_results':
            if type(h) == list:
                for t,y in enumerate(list_of_2015):
                    if h[0] == y:
                        v[g] = {'result':h[0],'standings':h[1],'result_rank':t+1}
        if g == '2016_results':
            if type(h) == list:
                for t,y in enumerate(list_of_2016):
                    if h[0] == y:
                        v[g] = {'result':h[0],'standings':h[1],'result_rank':t+1}
        if g == '2017_results':
            if type(h) == list:
                for t,y in enumerate(list_of_2017):
                    if h[0] == y:
                        v[g] = {'result':h[0],'standings':h[1],'result_rank':t+1}
        if g == '2018_results':
            if type(h) == list:
                for t,y in enumerate(list_of_2018):
                    if h[0] == y:
                        v[g] = {'result':h[0],'standings':h[1],'result_rank':t+1}
        if g == '2019_results':
            if type(h) == list:
                for t,y in enumerate(list_of_2019):
                    if h[0] == y:
                        v[g] = {'result':h[0],'standings':h[1],'result_rank':t+1}

# results_and_standing_dict['Winnipeg Jets']

# %%
teams = []
for k,v in rename_dict.items():
    teams.append(v)
for z,x in results_and_standing_dict.items():
    for team in set(teams):
        if team == z:
            for r,t in x.items():
                print(r,t)
#             print(team)
# Out:
# 2010_results {'result': -1014.5425627529203, 'standings': 17, 'result_rank': 14}
# 2011_results {'result': 12052.577409723002, 'standings': 9, 'result_rank': 1}
# 2012_results {'result': -11566.477159102811, 'standings': 26, 'result_rank': 28}
# 2013_results {'result': 10973.470924216925, 'standings': 3, 'result_rank': 2}
# 2014_results {'result': 7832.31978270031, 'standings': 2, 'result_rank': 2}
# 2015_results {'result': 9781.03037294419, 'standings': 3, 'result_rank': 3}
# 2016_results {'result': 985.0074671319456, 'standings': 7, 'result_rank': 9}
# 2017_results {'result': 1034.31773710792, 'standings': 6, 'result_rank': 12}
# 2018_results {'result': -2438.7038682106377, 'standings': 9, 'result_rank': 17}
# 2019_results {'result': -6864.454275980539, 'standings': 24, 'result_rank': 20}
# 2010_results {'result': 4483.164983164983, 'standings': 4, 'result_rank': 10}
# 2011_results {'result': 8211.400081400083, 'standings': 11, 'result_rank': 2}
# 2012_results {'result': 1919.0476190476197, 'standings': 11, 'result_rank': 9}
# 2013_results {'result': -5347.619047619048, 'standings': 19, 'result_rank': 23}
# 2014_results {'result': -8605.194805194806, 'standings': 18, 'result_rank': 24}
# 2015_results {'result': -24203.454899746466, 'standings': 29, 'result_rank': 31}
# 2016_results {'result': -1895.6451023017744, 'standings': 24, 'result_rank': 16}
# 2017_results {'result': -4856.448723690103, 'standings': 27, 'result_rank': 20}
# 2018_results {'result': -14737.313089487003, 'standings': 29, 'result_rank': 26}
# 2019_results {'result': 1881.5999124450236, 'standings': 18, 'result_rank': 9}
# 2010_results {'result': -11143.22827827152, 'standings': 14, 'result_rank': 27}
# 2011_results {'result': 2664.9401958880526, 'standings': 7, 'result_rank': 10}
# 2012_results {'result': -1636.3836472679527, 'standings': 7, 'result_rank': 14}
# 2013_results {'result': -3001.5271944412652, 'standings': 5, 'result_rank': 19}
# 2014_results {'result': 7452.596439806915, 'standings': 1, 'result_rank': 3}
# 2015_results {'result': -8878.510814621743, 'standings': 17, 'result_rank': 22}
# 2016_results {'result': -4533.7659882095995, 'standings': 15, 'result_rank': 19}
# 2017_results {'result': -4649.484768491939, 'standings': 13, 'result_rank': 19}
# 2018_results {'result': 5542.519352956937, 'standings': 4, 'result_rank': 8}
# 2019_results {'result': 2610.0227434943336, 'standings': 3, 'result_rank': 7}
# 2010_results {'result': -3895.8845389777603, 'standings': 11, 'result_rank': 19}
# 2011_results {'result': 120.39608962177044, 'standings': 15, 'result_rank': 16}
# 2012_results {'result': -6393.468311937938, 'standings': 19, 'result_rank': 23}
# 2013_results {'result': -2222.5911769390023, 'standings': 22, 'result_rank': 15}
# 2014_results {'result': -30165.23809523809, 'standings': 30, 'result_rank': 31}
# 2015_results {'result': -13270.0, 'standings': 30, 'result_rank': 26}
# 2016_results {'result': 1274.6701124962, 'standings': 23, 'result_rank': 7}
# 2017_results {'result': -8112.760572760573, 'standings': 26, 'result_rank': 23}
# 2018_results {'result': -18266.92679634209, 'standings': 31, 'result_rank': 30}
# 2019_results {'result': -12463.616294281584, 'standings': 27, 'result_rank': 29}
# 2010_results {'result': -4751.819144893149, 'standings': 15, 'result_rank': 21}
# 2011_results {'result': -6133.18090214642, 'standings': 17, 'result_rank': 24}
# 2012_results {'result': -6693.7128373821315, 'standings': 17, 'result_rank': 25}
# 2013_results {'result': -5544.9554471293595, 'standings': 25, 'result_rank': 24}
# 2014_results {'result': 2193.570843570843, 'standings': 27, 'result_rank': 9}
# 2015_results {'result': 11614.135650959453, 'standings': 16, 'result_rank': 1}
# 2016_results {'result': -6645.447488981852, 'standings': 26, 'result_rank': 22}
# 2017_results {'result': 2930.3936499531196, 'standings': 15, 'result_rank': 8}
# 2018_results {'result': -8894.302040665356, 'standings': 20, 'result_rank': 21}
# 2019_results {'result': 5033.07558832766, 'standings': 2, 'result_rank': 3}
# 2010_results {'result': -7690.34752453406, 'standings': 24, 'result_rank': 24}
# 2011_results {'result': -9213.164766502252, 'standings': 19, 'result_rank': 25}
# 2012_results {'result': -9274.863705993976, 'standings': 23, 'result_rank': 27}
# 2013_results {'result': -9155.333122376152, 'standings': 26, 'result_rank': 25}
# 2014_results {'result': -5587.253387892774, 'standings': 24, 'result_rank': 21}
# 2015_results {'result': -15498.177359434758, 'standings': 26, 'result_rank': 27}
# 2016_results {'result': -8433.986013986014, 'standings': 18, 'result_rank': 25}
# 2017_results {'result': -8834.732663613975, 'standings': 21, 'result_rank': 24}
# 2018_results {'result': -11178.141477998492, 'standings': 21, 'result_rank': 23}
# 2019_results {'result': 3117.80067472295, 'standings': 11, 'result_rank': 6}
# 2010_results {'result': 4491.094686575612, 'standings': 3, 'result_rank': 9}
# 2011_results {'result': -3932.1083986904046, 'standings': 13, 'result_rank': 20}
# 2012_results {'result': -1282.3735879627986, 'standings': 10, 'result_rank': 12}
# 2013_results {'result': 10398.318730736393, 'standings': 1, 'result_rank': 3}
# 2014_results {'result': -4119.706391081437, 'standings': 7, 'result_rank': 20}
# 2015_results {'result': -1803.1730431331516, 'standings': 7, 'result_rank': 19}
# 2016_results {'result': -1965.0938373238082, 'standings': 5, 'result_rank': 17}
# 2017_results {'result': 5510.854802862476, 'standings': 3, 'result_rank': 6}
# 2018_results {'result': -17925.85196626118, 'standings': 25, 'result_rank': 29}
# 2019_results {'result': -4575.544773264248, 'standings': 20, 'result_rank': 18}
# 2010_results {'result': 4758.837271908541, 'standings': 12, 'result_rank': 8}
# 2011_results {'result': -19610.762015762015, 'standings': 29, 'result_rank': 30}
# 2012_results {'result': 9142.307117891825, 'standings': 20, 'result_rank': 2}
# 2013_results {'result': -13850.544476836038, 'standings': 29, 'result_rank': 29}
# 2014_results {'result': 13788.160671556612, 'standings': 3, 'result_rank': 1}
# 2015_results {'result': 901.7671134239057, 'standings': 21, 'result_rank': 15}
# 2016_results {'result': 3023.9670734215106, 'standings': 21, 'result_rank': 6}
# 2017_results {'result': -27157.532467532466, 'standings': 30, 'result_rank': 31}
# 2018_results {'result': 7995.661435905333, 'standings': 17, 'result_rank': 5}
# 2019_results {'result': -8214.629402287046, 'standings': 17, 'result_rank': 23}
# 2010_results {'result': -17722.87860953528, 'standings': 27, 'result_rank': 31}
# 2011_results {'result': -10029.917508873865, 'standings': 24, 'result_rank': 26}
# 2012_results {'result': -13474.410774410775, 'standings': 30, 'result_rank': 29}
# 2013_results {'result': 8049.670619235836, 'standings': 17, 'result_rank': 4}
# 2014_results {'result': -136.46282223714115, 'standings': 14, 'result_rank': 14}
# 2015_results {'result': 9602.892309919935, 'standings': 22, 'result_rank': 4}
# 2016_results {'result': -8468.700253048079, 'standings': 27, 'result_rank': 26}
# 2017_results {'result': 10406.188226614417, 'standings': 4, 'result_rank': 1}
# 2018_results {'result': -1054.512500490655, 'standings': 14, 'result_rank': 15}
# 2019_results {'result': -498.7811116824854, 'standings': 13, 'result_rank': 11}
# 2010_results {'result': -6722.8181413557795, 'standings': 20, 'result_rank': 23}
# 2011_results {'result': 3187.678963132427, 'standings': 16, 'result_rank': 9}
# 2012_results {'result': 2394.286560652784, 'standings': 18, 'result_rank': 8}
# 2013_results {'result': 2412.350210176297, 'standings': 21, 'result_rank': 8}
# 2014_results {'result': -3424.724402826727, 'standings': 16, 'result_rank': 19}
# 2015_results {'result': -198.27509493176638, 'standings': 19, 'result_rank': 17}
# 2016_results {'result': 9670.648002041353, 'standings': 2, 'result_rank': 2}
# 2017_results {'result': -13816.966768609564, 'standings': 24, 'result_rank': 29}
# 2018_results {'result': -3408.6496889067575, 'standings': 19, 'result_rank': 19}
# 2019_results {'result': -2925.277200888935, 'standings': 15, 'result_rank': 14}
# 2010_results {'result': -1485.5206533952694, 'standings': 7, 'result_rank': 15}
# 2011_results {'result': -222.31022031716293, 'standings': 6, 'result_rank': 18}
# 2012_results {'result': -1486.8628548863207, 'standings': 8, 'result_rank': 13}
# 2013_results {'result': -2654.555842045139, 'standings': 14, 'result_rank': 16}
# 2014_results {'result': -6168.438671421053, 'standings': 15, 'result_rank': 22}
# 2015_results {'result': -5921.076100669367, 'standings': 12, 'result_rank': 20}
# 2016_results {'result': -6053.50882509803, 'standings': 16, 'result_rank': 20}
# 2017_results {'result': -11306.708233068683, 'standings': 25, 'result_rank': 26}
# 2018_results {'result': -16155.1818873558, 'standings': 27, 'result_rank': 27}
# 2019_results {'result': -1888.004237419531, 'standings': 28, 'result_rank': 12}
# 2010_results {'result': -14665.866713108095, 'standings': 30, 'result_rank': 28}
# 2011_results {'result': -20413.539793539792, 'standings': 30, 'result_rank': 31}
# 2012_results {'result': -5744.620766700857, 'standings': 29, 'result_rank': 21}
# 2013_results {'result': -9853.701470942851, 'standings': 24, 'result_rank': 26}
# 2014_results {'result': -17312.793074723086, 'standings': 28, 'result_rank': 30}
# 2015_results {'result': -19948.383838383837, 'standings': 28, 'result_rank': 30}
# 2016_results {'result': -14430.404059819351, 'standings': 29, 'result_rank': 31}
# 2017_results {'result': 2394.3057487775895, 'standings': 7, 'result_rank': 10}
# 2018_results {'result': -10296.526192562638, 'standings': 23, 'result_rank': 22}
# 2019_results {'result': -11750.263502276124, 'standings': 25, 'result_rank': 27}
# 2010_results {'result': -8305.683410098703, 'standings': 28, 'result_rank': 25}
# 2011_results {'result': -17981.508512800076, 'standings': 28, 'result_rank': 29}
# 2012_results {'result': -5096.569108420441, 'standings': 14, 'result_rank': 20}
# 2013_results {'result': -13398.484848484848, 'standings': 30, 'result_rank': 28}
# 2014_results {'result': -14280.151515151516, 'standings': 29, 'result_rank': 29}
# 2015_results {'result': -1130.065233693751, 'standings': 20, 'result_rank': 18}
# 2016_results {'result': 4064.691805760384, 'standings': 6, 'result_rank': 5}
# 2017_results {'result': -12989.984601089936, 'standings': 23, 'result_rank': 28}
# 2018_results {'result': 1882.775037984099, 'standings': 16, 'result_rank': 10}
# 2019_results {'result': -9342.848304823096, 'standings': 19, 'result_rank': 25}
# 2010_results {'result': 7151.984843086791, 'standings': 9, 'result_rank': 3}
# 2011_results {'result': 2441.488636730157, 'standings': 12, 'result_rank': 11}
# 2012_results {'result': -6410.721734444618, 'standings': 13, 'result_rank': 24}
# 2013_results {'result': -3289.037715405176, 'standings': 7, 'result_rank': 20}
# 2014_results {'result': 1036.0362066181024, 'standings': 9, 'result_rank': 11}
# 2015_results {'result': -13071.399841625762, 'standings': 18, 'result_rank': 25}
# 2016_results {'result': -87.32914646888344, 'standings': 8, 'result_rank': 13}
# 2017_results {'result': -10217.16962156384, 'standings': 22, 'result_rank': 25}
# 2018_results {'result': 685.4477410275364, 'standings': 12, 'result_rank': 11}
# 2019_results {'result': -14065.884518058432, 'standings': 30, 'result_rank': 30}
# 2010_results {'result': 26.833645076136236, 'standings': 22, 'result_rank': 11}
# 2011_results {'result': -792.9153819313997, 'standings': 21, 'result_rank': 19}
# 2012_results {'result': -8119.2848408740465, 'standings': 24, 'result_rank': 26}
# 2013_results {'result': 1992.4666031451343, 'standings': 15, 'result_rank': 10}
# 2014_results {'result': -206.8269383084462, 'standings': 11, 'result_rank': 15}
# 2015_results {'result': 1618.0391361916004, 'standings': 11, 'result_rank': 14}
# 2016_results {'result': -11802.351622803359, 'standings': 17, 'result_rank': 28}
# 2017_results {'result': 7316.654121795444, 'standings': 5, 'result_rank': 3}
# 2018_results {'result': -43.691402742755145, 'standings': 8, 'result_rank': 12}
# 2019_results {'result': -11858.481898225842, 'standings': 21, 'result_rank': 28}
# 2010_results {'result': -2401.9277490078384, 'standings': 19, 'result_rank': 16}
# 2011_results {'result': 5605.592800112003, 'standings': 14, 'result_rank': 4}
# 2012_results {'result': -18304.286275942948, 'standings': 28, 'result_rank': 31}
# 2013_results {'result': 6436.019027316547, 'standings': 4, 'result_rank': 5}
# 2014_results {'result': 5272.641646954745, 'standings': 10, 'result_rank': 5}
# 2015_results {'result': 6336.208452120408, 'standings': 2, 'result_rank': 6}
# 2016_results {'result': -7677.794620868624, 'standings': 22, 'result_rank': 24}
# 2017_results {'result': 2920.273383452686, 'standings': 8, 'result_rank': 9}
# 2018_results {'result': -25525.931658582245, 'standings': 28, 'result_rank': 31}
# 2019_results {'result': 3945.3093725898966, 'standings': 14, 'result_rank': 5}
# 2010_results {'result': 10024.169215534344, 'standings': 10, 'result_rank': 2}
# 2011_results {'result': 6641.854846140646, 'standings': 10, 'result_rank': 3}
# 2012_results {'result': 3226.7191144230574, 'standings': 5, 'result_rank': 7}
# 2013_results {'result': -17398.118548118546, 'standings': 27, 'result_rank': 31}
# 2014_results {'result': 4285.154439446163, 'standings': 19, 'result_rank': 8}
# 2015_results {'result': 1857.1802740420758, 'standings': 6, 'result_rank': 13}
# 2016_results {'result': -7564.185893119452, 'standings': 13, 'result_rank': 23}
# 2017_results {'result': -6069.583535025724, 'standings': 17, 'result_rank': 22}
# 2018_results {'result': 8869.128453270787, 'standings': 1, 'result_rank': 4}
# 2019_results {'result': 128.33539029574513, 'standings': 7, 'result_rank': 10}
# 2010_results {'result': 5361.783653583512, 'standings': 6, 'result_rank': 7}
# 2011_results {'result': -6075.320656450925, 'standings': 23, 'result_rank': 23}
# 2012_results {'result': 13343.017792378407, 'standings': 9, 'result_rank': 1}
# 2013_results {'result': -12689.80697664908, 'standings': 23, 'result_rank': 27}
# 2014_results {'result': -9205.902082193643, 'standings': 21, 'result_rank': 26}
# 2015_results {'result': -17784.267502819872, 'standings': 25, 'result_rank': 28}
# 2016_results {'result': 465.19921302529997, 'standings': 20, 'result_rank': 11}
# 2017_results {'result': -22134.07529003504, 'standings': 28, 'result_rank': 30}
# 2018_results {'result': 11206.759790349612, 'standings': 15, 'result_rank': 2}
# 2019_results {'result': -15618.437857742589, 'standings': 29, 'result_rank': 31}
# 2010_results {'result': -2901.9902386469093, 'standings': 26, 'result_rank': 17}
# 2011_results {'result': -12454.72049689441, 'standings': 27, 'result_rank': 28}
# 2012_results {'result': -3428.292312546315, 'standings': 27, 'result_rank': 16}
# 2013_results {'result': 1374.4037571623785, 'standings': 16, 'result_rank': 12}
# 2014_results {'result': -3289.678871852784, 'standings': 26, 'result_rank': 18}
# 2015_results {'result': 5021.2612685762815, 'standings': 9, 'result_rank': 7}
# 2016_results {'result': -1291.3474786435359, 'standings': 10, 'result_rank': 14}
# 2017_results {'result': 1815.6245629683517, 'standings': 18, 'result_rank': 11}
# 2018_results {'result': -13867.235561353207, 'standings': 22, 'result_rank': 24}
# 2019_results {'result': 12676.078601576683, 'standings': 5, 'result_rank': 2}
# 2010_results {'result': -8517.765008241684, 'standings': 21, 'result_rank': 26}
# 2011_results {'result': 4780.966987434048, 'standings': 18, 'result_rank': 6}
# 2012_results {'result': 8502.769567411655, 'standings': 2, 'result_rank': 3}
# 2013_results {'result': -2696.6737863206463, 'standings': 12, 'result_rank': 17}
# 2014_results {'result': 4721.632844739617, 'standings': 12, 'result_rank': 6}
# 2015_results {'result': 11204.812755844183, 'standings': 1, 'result_rank': 2}
# 2016_results {'result': -1825.5139315645174, 'standings': 9, 'result_rank': 15}
# 2017_results {'result': 6523.113024916876, 'standings': 9, 'result_rank': 5}
# 2018_results {'result': -14178.38269313697, 'standings': 24, 'result_rank': 25}
# 2019_results {'result': -9403.260167446704, 'standings': 26, 'result_rank': 26}
# 2010_results {'result': 6450.238109497954, 'standings': 13, 'result_rank': 4}
# 2011_results {'result': -10907.241892080601, 'standings': 26, 'result_rank': 27}
# 2012_results {'result': 3606.1224996945857, 'standings': 16, 'result_rank': 6}
# 2013_results {'result': 1847.8974042281097, 'standings': 13, 'result_rank': 11}
# 2014_results {'result': -10302.273873769256, 'standings': 20, 'result_rank': 27}
# 2015_results {'result': 3413.428529350029, 'standings': 13, 'result_rank': 9}
# 2016_results {'result': -6118.889465181028, 'standings': 19, 'result_rank': 21}
# 2017_results {'result': 7476.277834853448, 'standings': 12, 'result_rank': 2}
# 2018_results {'result': -17092.195263784466, 'standings': 30, 'result_rank': 28}
# 2019_results {'result': -8583.225693225693, 'standings': 31, 'result_rank': 24}
# 2010_results {'result': -6025.632959736731, 'standings': 18, 'result_rank': 22}
# 2011_results {'result': 1619.488262232252, 'standings': 4, 'result_rank': 12}
# 2012_results {'result': 473.78552906873165, 'standings': 6, 'result_rank': 10}
# 2013_results {'result': -2886.5727358267377, 'standings': 20, 'result_rank': 18}
# 2014_results {'result': 1658.9237833782206, 'standings': 13, 'result_rank': 10}
# 2015_results {'result': -12839.405324653242, 'standings': 24, 'result_rank': 24}
# 2016_results {'result': 1261.7998047871815, 'standings': 14, 'result_rank': 8}
# 2017_results {'result': -4524.453926817451, 'standings': 19, 'result_rank': 18}
# 2018_results {'result': -1878.667543146511, 'standings': 13, 'result_rank': 16}
# 2019_results {'result': -8160.976246487644, 'standings': 22, 'result_rank': 22}
# 2010_results {'result': -3326.2612122112523, 'standings': 8, 'result_rank': 18}
# 2011_results {'result': 5360.603460225964, 'standings': 3, 'result_rank': 5}
# 2012_results {'result': 4457.29127107445, 'standings': 4, 'result_rank': 5}
# 2013_results {'result': 12925.282135364592, 'standings': 2, 'result_rank': 1}
# 2014_results {'result': 4589.045981484669, 'standings': 6, 'result_rank': 7}
# 2015_results {'result': -11883.413598693554, 'standings': 15, 'result_rank': 23}
# 2016_results {'result': 4970.332055799082, 'standings': 4, 'result_rank': 4}
# 2017_results {'result': -515.8472069213836, 'standings': 2, 'result_rank': 14}
# 2018_results {'result': -3176.658992072699, 'standings': 10, 'result_rank': 18}
# 2019_results {'result': -6328.171717901533, 'standings': 9, 'result_rank': 19}
# 2010_results {'result': -634.8175857692083, 'standings': 2, 'result_rank': 13}
# 2011_results {'result': 368.2126505063384, 'standings': 5, 'result_rank': 15}
# 2012_results {'result': -2306.166969279304, 'standings': 12, 'result_rank': 15}
# 2013_results {'result': -3543.0376109823146, 'standings': 11, 'result_rank': 21}
# 2014_results {'result': -634.7715244330275, 'standings': 5, 'result_rank': 16}
# 2015_results {'result': -6668.6604465070495, 'standings': 23, 'result_rank': 21}
# 2016_results {'result': 743.0144135799578, 'standings': 11, 'result_rank': 10}
# 2017_results {'result': -1665.5015622487306, 'standings': 10, 'result_rank': 15}
# 2018_results {'result': -901.7777472422968, 'standings': 11, 'result_rank': 14}
# 2019_results {'result': -3114.9644750769485, 'standings': 6, 'result_rank': 15}
# 2010_results {'result': 10680.712250712251, 'standings': 16, 'result_rank': 1}
# 2011_results {'result': -5638.528138528139, 'standings': 20, 'result_rank': 21}
# 2012_results {'result': -4844.35974653366, 'standings': 3, 'result_rank': 19}
# 2013_results {'result': 2334.3572880657275, 'standings': 6, 'result_rank': 9}
# 2014_results {'result': 385.724203303232, 'standings': 4, 'result_rank': 12}
# 2015_results {'result': 2813.676087764824, 'standings': 4, 'result_rank': 11}
# 2016_results {'result': 7635.803208629295, 'standings': 3, 'result_rank': 3}
# 2017_results {'result': 3973.5592122001863, 'standings': 11, 'result_rank': 7}
# 2018_results {'result': -717.9940728327823, 'standings': 18, 'result_rank': 13}
# 2019_results {'result': 4671.367422289856, 'standings': 12, 'result_rank': 4}
# 2010_results {'result': -15407.804794461466, 'standings': 25, 'result_rank': 29}
# 2011_results {'result': 3812.76478939314, 'standings': 8, 'result_rank': 8}
# 2012_results {'result': -3496.8588903918303, 'standings': 21, 'result_rank': 17}
# 2013_results {'result': -14468.14960401917, 'standings': 28, 'result_rank': 30}
# 2014_results {'result': 6058.049254761362, 'standings': 8, 'result_rank': 4}
# 2015_results {'result': 2620.7874826638545, 'standings': 5, 'result_rank': 12}
# 2016_results {'result': -3415.827538854982, 'standings': 12, 'result_rank': 18}
# 2017_results {'result': -3833.8573985902017, 'standings': 16, 'result_rank': 16}
# 2018_results {'result': 6143.02078486674, 'standings': 3, 'result_rank': 6}
# 2019_results {'result': 18130.318385035964, 'standings': 1, 'result_rank': 1}
# 2010_results {'result': -16664.16022785588, 'standings': 29, 'result_rank': 30}
# 2011_results {'result': -5790.000965707817, 'standings': 22, 'result_rank': 22}
# 2012_results {'result': -13489.58727885902, 'standings': 25, 'result_rank': 30}
# 2013_results {'result': 3934.7080053601785, 'standings': 10, 'result_rank': 7}
# 2014_results {'result': -7029.498806252171, 'standings': 22, 'result_rank': 23}
# 2015_results {'result': -18481.898354574518, 'standings': 27, 'result_rank': 29}
# 2016_results {'result': -13961.076025423852, 'standings': 30, 'result_rank': 30}
# 2017_results {'result': -4229.575833177477, 'standings': 14, 'result_rank': 17}
# 2018_results {'result': 5992.221128853864, 'standings': 6, 'result_rank': 7}
# 2019_results {'result': -2444.892991589447, 'standings': 8, 'result_rank': 13}
# 2010_results {'result': 5963.415811822594, 'standings': 5, 'result_rank': 5}
# 2011_results {'result': 4668.369653862336, 'standings': 1, 'result_rank': 7}
# 2012_results {'result': 4543.6588197560795, 'standings': 1, 'result_rank': 4}
# 2013_results {'result': -3592.4012850106446, 'standings': 8, 'result_rank': 22}
# 2014_results {'result': -13874.773982496325, 'standings': 25, 'result_rank': 28}
# 2015_results {'result': 6465.117586448532, 'standings': 8, 'result_rank': 5}
# 2016_results {'result': -13117.02652420044, 'standings': 28, 'result_rank': 29}
# 2017_results {'result': -12444.526494186175, 'standings': 29, 'result_rank': 27}
# 2018_results {'result': -6536.019198193111, 'standings': 26, 'result_rank': 20}
# 2019_results {'result': -3180.1389436718837, 'standings': 23, 'result_rank': 16}
# 2010_results 0.0
# 2011_results 0.0
# 2012_results 0.0
# 2013_results 0.0
# 2014_results 0.0
# 2015_results 0.0
# 2016_results 0.0
# 2017_results 0.0
# 2018_results {'result': 17370.906849105795, 'standings': 5, 'result_rank': 1}
# 2019_results {'result': -7480.90873897896, 'standings': 16, 'result_rank': 21}
# 2010_results {'result': 5616.217331904449, 'standings': 1, 'result_rank': 6}
# 2011_results {'result': 557.1772138672922, 'standings': 2, 'result_rank': 14}
# 2012_results {'result': -5864.146682299852, 'standings': 15, 'result_rank': 22}
# 2013_results {'result': 4461.90416665625, 'standings': 9, 'result_rank': 6}
# 2014_results {'result': -8994.828773591893, 'standings': 17, 'result_rank': 25}
# 2015_results {'result': 3124.0509482193793, 'standings': 10, 'result_rank': 10}
# 2016_results {'result': 10364.799480518892, 'standings': 1, 'result_rank': 1}
# 2017_results {'result': 6921.371541565641, 'standings': 1, 'result_rank': 4}
# 2018_results {'result': 3449.948660295461, 'standings': 7, 'result_rank': 9}
# 2019_results {'result': 1945.4825468072522, 'standings': 4, 'result_rank': 8}
# 2010_results {'result': -4688.528138528139, 'standings': 23, 'result_rank': 20}
# 2011_results {'result': 883.8509316770187, 'standings': 25, 'result_rank': 13}
# 2012_results {'result': -4204.3100307379445, 'standings': 22, 'result_rank': 18}
# 2013_results {'result': -727.1318167950259, 'standings': 18, 'result_rank': 14}
# 2014_results {'result': -2105.4280667870953, 'standings': 23, 'result_rank': 17}
# 2015_results {'result': 4516.583142548747, 'standings': 14, 'result_rank': 8}
# 2016_results {'result': -10032.531338788735, 'standings': 25, 'result_rank': 27}
# 2017_results {'result': -5473.45992504913, 'standings': 20, 'result_rank': 21}
# 2018_results {'result': 10409.294278454598, 'standings': 2, 'result_rank': 3}
# 2019_results {'result': -3801.3287854783766, 'standings': 10, 'result_rank': 17}

# %%
new_dict = {}
new_dict['2010'] = []
new_dict['2011'] = []
new_dict['2012'] = []
new_dict['2013'] = []
new_dict['2014'] = []
new_dict['2015'] = []
new_dict['2016'] = []
new_dict['2017'] = []
new_dict['2018'] = []
new_dict['2019'] = []
for k,v in results_and_standing_dict.items():
    for z,x in v.items():
        if z == '2010_results':
            if k != 'Vegas Golden Knights':
                new_dict['2010'].append({'team':k,'standings':x['standings'],'rank':x['result_rank']})
        if z == '2011_results':
            if k != 'Vegas Golden Knights':
                new_dict['2011'].append({'team':k,'standings':x['standings'],'rank':x['result_rank']})
        if z == '2012_results':
            if k != 'Vegas Golden Knights':
                new_dict['2012'].append({'team':k,'standings':x['standings'],'rank':x['result_rank']})
        if z == '2013_results':
            if k != 'Vegas Golden Knights':
                new_dict['2013'].append({'team':k,'standings':x['standings'],'rank':x['result_rank']})
        if z == '2014_results':
            if k != 'Vegas Golden Knights':
                new_dict['2014'].append({'team':k,'standings':x['standings'],'rank':x['result_rank']})
        if z == '2015_results':
            if k != 'Vegas Golden Knights':
                new_dict['2015'].append({'team':k,'standings':x['standings'],'rank':x['result_rank']})
        if z == '2016_results':
            if k != 'Vegas Golden Knights':
                new_dict['2016'].append({'team':k,'standings':x['standings'],'rank':x['result_rank']})
        if z == '2017_results':
            if k != 'Vegas Golden Knights':
                new_dict['2017'].append({'team':k,'standings':x['standings'],'rank':x['result_rank']})
        if z == '2018_results':
            new_dict['2018'].append({'team':k,'standings':x['standings'],'rank':x['result_rank']})
        if z == '2019_results':
            new_dict['2019'].append({'team':k,'standings':x['standings'],'rank':x['result_rank']})
                
standings_vs_rank = new_dict
standings_vs_rank
# Out:
# {'2010': [{'team': 'Anaheim Ducks', 'standings': 17, 'rank': 14},
#   {'team': 'Arizona Coyotes', 'standings': 4, 'rank': 10},
#   {'team': 'Boston Bruins', 'standings': 14, 'rank': 27},
#   {'team': 'Buffalo Sabres', 'standings': 11, 'rank': 19},
#   {'team': 'Calgary Flames', 'standings': 15, 'rank': 21},
#   {'team': 'Carolina Hurricanes', 'standings': 24, 'rank': 24},
#   {'team': 'Chicago Blackhawks', 'standings': 3, 'rank': 9},
#   {'team': 'Colorado Avalanche', 'standings': 12, 'rank': 8},
#   {'team': 'Columbus Blue Jackets', 'standings': 27, 'rank': 31},
#   {'team': 'Dallas Stars', 'standings': 20, 'rank': 23},
#   {'team': 'Detroit Red Wings', 'standings': 7, 'rank': 15},
#   {'team': 'Edmonton Oilers', 'standings': 30, 'rank': 28},
#   {'team': 'Florida Panthers', 'standings': 28, 'rank': 25},
#   {'team': 'Los Angeles Kings', 'standings': 9, 'rank': 3},
#   {'team': 'Minnesota Wild', 'standings': 22, 'rank': 11},
#   {'team': 'Montreal Canadiens', 'standings': 19, 'rank': 16},
#   {'team': 'Nashville Predators', 'standings': 10, 'rank': 2},
#   {'team': 'New Jersey Devils', 'standings': 6, 'rank': 7},
#   {'team': 'New York Islanders', 'standings': 26, 'rank': 17},
#   {'team': 'New York Rangers', 'standings': 21, 'rank': 26},
#   {'team': 'Ottawa Senators', 'standings': 13, 'rank': 4},
#   {'team': 'Philadelphia Flyers', 'standings': 18, 'rank': 22},
#   {'team': 'Pittsburgh Penguins', 'standings': 8, 'rank': 18},
#   {'team': 'San Jose Sharks', 'standings': 2, 'rank': 13},
#   {'team': 'St Louis Blues', 'standings': 16, 'rank': 1},
#   {'team': 'Tampa Bay Lightning', 'standings': 25, 'rank': 29},
#   {'team': 'Toronto Maple Leafs', 'standings': 29, 'rank': 30},
#   {'team': 'Vancouver Canucks', 'standings': 5, 'rank': 5},
#   {'team': 'Washington Capitals', 'standings': 1, 'rank': 6},
#   {'team': 'Winnipeg Jets', 'standings': 23, 'rank': 20}],
#  '2011': [{'team': 'Anaheim Ducks', 'standings': 9, 'rank': 1},
#   {'team': 'Arizona Coyotes', 'standings': 11, 'rank': 2},
#   {'team': 'Boston Bruins', 'standings': 7, 'rank': 10},
#   {'team': 'Buffalo Sabres', 'standings': 15, 'rank': 16},
#   {'team': 'Calgary Flames', 'standings': 17, 'rank': 24},
#   {'team': 'Carolina Hurricanes', 'standings': 19, 'rank': 25},
#   {'team': 'Chicago Blackhawks', 'standings': 13, 'rank': 20},
#   {'team': 'Colorado Avalanche', 'standings': 29, 'rank': 30},
#   {'team': 'Columbus Blue Jackets', 'standings': 24, 'rank': 26},
#   {'team': 'Dallas Stars', 'standings': 16, 'rank': 9},
#   {'team': 'Detroit Red Wings', 'standings': 6, 'rank': 18},
#   {'team': 'Edmonton Oilers', 'standings': 30, 'rank': 31},
#   {'team': 'Florida Panthers', 'standings': 28, 'rank': 29},
#   {'team': 'Los Angeles Kings', 'standings': 12, 'rank': 11},
#   {'team': 'Minnesota Wild', 'standings': 21, 'rank': 19},
#   {'team': 'Montreal Canadiens', 'standings': 14, 'rank': 4},
#   {'team': 'Nashville Predators', 'standings': 10, 'rank': 3},
#   {'team': 'New Jersey Devils', 'standings': 23, 'rank': 23},
#   {'team': 'New York Islanders', 'standings': 27, 'rank': 28},
#   {'team': 'New York Rangers', 'standings': 18, 'rank': 6},
#   {'team': 'Ottawa Senators', 'standings': 26, 'rank': 27},
#   {'team': 'Philadelphia Flyers', 'standings': 4, 'rank': 12},
#   {'team': 'Pittsburgh Penguins', 'standings': 3, 'rank': 5},
#   {'team': 'San Jose Sharks', 'standings': 5, 'rank': 15},
#   {'team': 'St Louis Blues', 'standings': 20, 'rank': 21},
#   {'team': 'Tampa Bay Lightning', 'standings': 8, 'rank': 8},
#   {'team': 'Toronto Maple Leafs', 'standings': 22, 'rank': 22},
#   {'team': 'Vancouver Canucks', 'standings': 1, 'rank': 7},
#   {'team': 'Washington Capitals', 'standings': 2, 'rank': 14},
#   {'team': 'Winnipeg Jets', 'standings': 25, 'rank': 13}],
#  '2012': [{'team': 'Anaheim Ducks', 'standings': 26, 'rank': 28},
#   {'team': 'Arizona Coyotes', 'standings': 11, 'rank': 9},
#   {'team': 'Boston Bruins', 'standings': 7, 'rank': 14},
#   {'team': 'Buffalo Sabres', 'standings': 19, 'rank': 23},
#   {'team': 'Calgary Flames', 'standings': 17, 'rank': 25},
#   {'team': 'Carolina Hurricanes', 'standings': 23, 'rank': 27},
#   {'team': 'Chicago Blackhawks', 'standings': 10, 'rank': 12},
#   {'team': 'Colorado Avalanche', 'standings': 20, 'rank': 2},
#   {'team': 'Columbus Blue Jackets', 'standings': 30, 'rank': 29},
#   {'team': 'Dallas Stars', 'standings': 18, 'rank': 8},
#   {'team': 'Detroit Red Wings', 'standings': 8, 'rank': 13},
#   {'team': 'Edmonton Oilers', 'standings': 29, 'rank': 21},
#   {'team': 'Florida Panthers', 'standings': 14, 'rank': 20},
#   {'team': 'Los Angeles Kings', 'standings': 13, 'rank': 24},
#   {'team': 'Minnesota Wild', 'standings': 24, 'rank': 26},
#   {'team': 'Montreal Canadiens', 'standings': 28, 'rank': 31},
#   {'team': 'Nashville Predators', 'standings': 5, 'rank': 7},
#   {'team': 'New Jersey Devils', 'standings': 9, 'rank': 1},
#   {'team': 'New York Islanders', 'standings': 27, 'rank': 16},
#   {'team': 'New York Rangers', 'standings': 2, 'rank': 3},
#   {'team': 'Ottawa Senators', 'standings': 16, 'rank': 6},
#   {'team': 'Philadelphia Flyers', 'standings': 6, 'rank': 10},
#   {'team': 'Pittsburgh Penguins', 'standings': 4, 'rank': 5},
#   {'team': 'San Jose Sharks', 'standings': 12, 'rank': 15},
#   {'team': 'St Louis Blues', 'standings': 3, 'rank': 19},
#   {'team': 'Tampa Bay Lightning', 'standings': 21, 'rank': 17},
#   {'team': 'Toronto Maple Leafs', 'standings': 25, 'rank': 30},
#   {'team': 'Vancouver Canucks', 'standings': 1, 'rank': 4},
#   {'team': 'Washington Capitals', 'standings': 15, 'rank': 22},
#   {'team': 'Winnipeg Jets', 'standings': 22, 'rank': 18}],
#  '2013': [{'team': 'Anaheim Ducks', 'standings': 3, 'rank': 2},
#   {'team': 'Arizona Coyotes', 'standings': 19, 'rank': 23},
#   {'team': 'Boston Bruins', 'standings': 5, 'rank': 19},
#   {'team': 'Buffalo Sabres', 'standings': 22, 'rank': 15},
#   {'team': 'Calgary Flames', 'standings': 25, 'rank': 24},
#   {'team': 'Carolina Hurricanes', 'standings': 26, 'rank': 25},
#   {'team': 'Chicago Blackhawks', 'standings': 1, 'rank': 3},
#   {'team': 'Colorado Avalanche', 'standings': 29, 'rank': 29},
#   {'team': 'Columbus Blue Jackets', 'standings': 17, 'rank': 4},
#   {'team': 'Dallas Stars', 'standings': 21, 'rank': 8},
#   {'team': 'Detroit Red Wings', 'standings': 14, 'rank': 16},
#   {'team': 'Edmonton Oilers', 'standings': 24, 'rank': 26},
#   {'team': 'Florida Panthers', 'standings': 30, 'rank': 28},
#   {'team': 'Los Angeles Kings', 'standings': 7, 'rank': 20},
#   {'team': 'Minnesota Wild', 'standings': 15, 'rank': 10},
#   {'team': 'Montreal Canadiens', 'standings': 4, 'rank': 5},
#   {'team': 'Nashville Predators', 'standings': 27, 'rank': 31},
#   {'team': 'New Jersey Devils', 'standings': 23, 'rank': 27},
#   {'team': 'New York Islanders', 'standings': 16, 'rank': 12},
#   {'team': 'New York Rangers', 'standings': 12, 'rank': 17},
#   {'team': 'Ottawa Senators', 'standings': 13, 'rank': 11},
#   {'team': 'Philadelphia Flyers', 'standings': 20, 'rank': 18},
#   {'team': 'Pittsburgh Penguins', 'standings': 2, 'rank': 1},
#   {'team': 'San Jose Sharks', 'standings': 11, 'rank': 21},
#   {'team': 'St Louis Blues', 'standings': 6, 'rank': 9},
#   {'team': 'Tampa Bay Lightning', 'standings': 28, 'rank': 30},
#   {'team': 'Toronto Maple Leafs', 'standings': 10, 'rank': 7},
#   {'team': 'Vancouver Canucks', 'standings': 8, 'rank': 22},
#   {'team': 'Washington Capitals', 'standings': 9, 'rank': 6},
#   {'team': 'Winnipeg Jets', 'standings': 18, 'rank': 14}],
#  '2014': [{'team': 'Anaheim Ducks', 'standings': 2, 'rank': 2},
#   {'team': 'Arizona Coyotes', 'standings': 18, 'rank': 24},
#   {'team': 'Boston Bruins', 'standings': 1, 'rank': 3},
#   {'team': 'Buffalo Sabres', 'standings': 30, 'rank': 31},
#   {'team': 'Calgary Flames', 'standings': 27, 'rank': 9},
#   {'team': 'Carolina Hurricanes', 'standings': 24, 'rank': 21},
#   {'team': 'Chicago Blackhawks', 'standings': 7, 'rank': 20},
#   {'team': 'Colorado Avalanche', 'standings': 3, 'rank': 1},
#   {'team': 'Columbus Blue Jackets', 'standings': 14, 'rank': 14},
#   {'team': 'Dallas Stars', 'standings': 16, 'rank': 19},
#   {'team': 'Detroit Red Wings', 'standings': 15, 'rank': 22},
#   {'team': 'Edmonton Oilers', 'standings': 28, 'rank': 30},
#   {'team': 'Florida Panthers', 'standings': 29, 'rank': 29},
#   {'team': 'Los Angeles Kings', 'standings': 9, 'rank': 11},
#   {'team': 'Minnesota Wild', 'standings': 11, 'rank': 15},
#   {'team': 'Montreal Canadiens', 'standings': 10, 'rank': 5},
#   {'team': 'Nashville Predators', 'standings': 19, 'rank': 8},
#   {'team': 'New Jersey Devils', 'standings': 21, 'rank': 26},
#   {'team': 'New York Islanders', 'standings': 26, 'rank': 18},
#   {'team': 'New York Rangers', 'standings': 12, 'rank': 6},
#   {'team': 'Ottawa Senators', 'standings': 20, 'rank': 27},
#   {'team': 'Philadelphia Flyers', 'standings': 13, 'rank': 10},
#   {'team': 'Pittsburgh Penguins', 'standings': 6, 'rank': 7},
#   {'team': 'San Jose Sharks', 'standings': 5, 'rank': 16},
#   {'team': 'St Louis Blues', 'standings': 4, 'rank': 12},
#   {'team': 'Tampa Bay Lightning', 'standings': 8, 'rank': 4},
#   {'team': 'Toronto Maple Leafs', 'standings': 22, 'rank': 23},
#   {'team': 'Vancouver Canucks', 'standings': 25, 'rank': 28},
#   {'team': 'Washington Capitals', 'standings': 17, 'rank': 25},
#   {'team': 'Winnipeg Jets', 'standings': 23, 'rank': 17}],
#  '2015': [{'team': 'Anaheim Ducks', 'standings': 3, 'rank': 3},
#   {'team': 'Arizona Coyotes', 'standings': 29, 'rank': 31},
#   {'team': 'Boston Bruins', 'standings': 17, 'rank': 22},
#   {'team': 'Buffalo Sabres', 'standings': 30, 'rank': 26},
#   {'team': 'Calgary Flames', 'standings': 16, 'rank': 1},
#   {'team': 'Carolina Hurricanes', 'standings': 26, 'rank': 27},
#   {'team': 'Chicago Blackhawks', 'standings': 7, 'rank': 19},
#   {'team': 'Colorado Avalanche', 'standings': 21, 'rank': 15},
#   {'team': 'Columbus Blue Jackets', 'standings': 22, 'rank': 4},
#   {'team': 'Dallas Stars', 'standings': 19, 'rank': 17},
#   {'team': 'Detroit Red Wings', 'standings': 12, 'rank': 20},
#   {'team': 'Edmonton Oilers', 'standings': 28, 'rank': 30},
#   {'team': 'Florida Panthers', 'standings': 20, 'rank': 18},
#   {'team': 'Los Angeles Kings', 'standings': 18, 'rank': 25},
#   {'team': 'Minnesota Wild', 'standings': 11, 'rank': 14},
#   {'team': 'Montreal Canadiens', 'standings': 2, 'rank': 6},
#   {'team': 'Nashville Predators', 'standings': 6, 'rank': 13},
#   {'team': 'New Jersey Devils', 'standings': 25, 'rank': 28},
#   {'team': 'New York Islanders', 'standings': 9, 'rank': 7},
#   {'team': 'New York Rangers', 'standings': 1, 'rank': 2},
#   {'team': 'Ottawa Senators', 'standings': 13, 'rank': 9},
#   {'team': 'Philadelphia Flyers', 'standings': 24, 'rank': 24},
#   {'team': 'Pittsburgh Penguins', 'standings': 15, 'rank': 23},
#   {'team': 'San Jose Sharks', 'standings': 23, 'rank': 21},
#   {'team': 'St Louis Blues', 'standings': 4, 'rank': 11},
#   {'team': 'Tampa Bay Lightning', 'standings': 5, 'rank': 12},
#   {'team': 'Toronto Maple Leafs', 'standings': 27, 'rank': 29},
#   {'team': 'Vancouver Canucks', 'standings': 8, 'rank': 5},
#   {'team': 'Washington Capitals', 'standings': 10, 'rank': 10},
#   {'team': 'Winnipeg Jets', 'standings': 14, 'rank': 8}],
#  '2016': [{'team': 'Anaheim Ducks', 'standings': 7, 'rank': 9},
#   {'team': 'Arizona Coyotes', 'standings': 24, 'rank': 16},
#   {'team': 'Boston Bruins', 'standings': 15, 'rank': 19},
#   {'team': 'Buffalo Sabres', 'standings': 23, 'rank': 7},
#   {'team': 'Calgary Flames', 'standings': 26, 'rank': 22},
#   {'team': 'Carolina Hurricanes', 'standings': 18, 'rank': 25},
#   {'team': 'Chicago Blackhawks', 'standings': 5, 'rank': 17},
#   {'team': 'Colorado Avalanche', 'standings': 21, 'rank': 6},
#   {'team': 'Columbus Blue Jackets', 'standings': 27, 'rank': 26},
#   {'team': 'Dallas Stars', 'standings': 2, 'rank': 2},
#   {'team': 'Detroit Red Wings', 'standings': 16, 'rank': 20},
#   {'team': 'Edmonton Oilers', 'standings': 29, 'rank': 31},
#   {'team': 'Florida Panthers', 'standings': 6, 'rank': 5},
#   {'team': 'Los Angeles Kings', 'standings': 8, 'rank': 13},
#   {'team': 'Minnesota Wild', 'standings': 17, 'rank': 28},
#   {'team': 'Montreal Canadiens', 'standings': 22, 'rank': 24},
#   {'team': 'Nashville Predators', 'standings': 13, 'rank': 23},
#   {'team': 'New Jersey Devils', 'standings': 20, 'rank': 11},
#   {'team': 'New York Islanders', 'standings': 10, 'rank': 14},
#   {'team': 'New York Rangers', 'standings': 9, 'rank': 15},
#   {'team': 'Ottawa Senators', 'standings': 19, 'rank': 21},
#   {'team': 'Philadelphia Flyers', 'standings': 14, 'rank': 8},
#   {'team': 'Pittsburgh Penguins', 'standings': 4, 'rank': 4},
#   {'team': 'San Jose Sharks', 'standings': 11, 'rank': 10},
#   {'team': 'St Louis Blues', 'standings': 3, 'rank': 3},
#   {'team': 'Tampa Bay Lightning', 'standings': 12, 'rank': 18},
#   {'team': 'Toronto Maple Leafs', 'standings': 30, 'rank': 30},
#   {'team': 'Vancouver Canucks', 'standings': 28, 'rank': 29},
#   {'team': 'Washington Capitals', 'standings': 1, 'rank': 1},
#   {'team': 'Winnipeg Jets', 'standings': 25, 'rank': 27}],
#  '2017': [{'team': 'Anaheim Ducks', 'standings': 6, 'rank': 12},
#   {'team': 'Arizona Coyotes', 'standings': 27, 'rank': 20},
#   {'team': 'Boston Bruins', 'standings': 13, 'rank': 19},
#   {'team': 'Buffalo Sabres', 'standings': 26, 'rank': 23},
#   {'team': 'Calgary Flames', 'standings': 15, 'rank': 8},
#   {'team': 'Carolina Hurricanes', 'standings': 21, 'rank': 24},
#   {'team': 'Chicago Blackhawks', 'standings': 3, 'rank': 6},
#   {'team': 'Colorado Avalanche', 'standings': 30, 'rank': 31},
#   {'team': 'Columbus Blue Jackets', 'standings': 4, 'rank': 1},
#   {'team': 'Dallas Stars', 'standings': 24, 'rank': 29},
#   {'team': 'Detroit Red Wings', 'standings': 25, 'rank': 26},
#   {'team': 'Edmonton Oilers', 'standings': 7, 'rank': 10},
#   {'team': 'Florida Panthers', 'standings': 23, 'rank': 28},
#   {'team': 'Los Angeles Kings', 'standings': 22, 'rank': 25},
#   {'team': 'Minnesota Wild', 'standings': 5, 'rank': 3},
#   {'team': 'Montreal Canadiens', 'standings': 8, 'rank': 9},
#   {'team': 'Nashville Predators', 'standings': 17, 'rank': 22},
#   {'team': 'New Jersey Devils', 'standings': 28, 'rank': 30},
#   {'team': 'New York Islanders', 'standings': 18, 'rank': 11},
#   {'team': 'New York Rangers', 'standings': 9, 'rank': 5},
#   {'team': 'Ottawa Senators', 'standings': 12, 'rank': 2},
#   {'team': 'Philadelphia Flyers', 'standings': 19, 'rank': 18},
#   {'team': 'Pittsburgh Penguins', 'standings': 2, 'rank': 14},
#   {'team': 'San Jose Sharks', 'standings': 10, 'rank': 15},
#   {'team': 'St Louis Blues', 'standings': 11, 'rank': 7},
#   {'team': 'Tampa Bay Lightning', 'standings': 16, 'rank': 16},
#   {'team': 'Toronto Maple Leafs', 'standings': 14, 'rank': 17},
#   {'team': 'Vancouver Canucks', 'standings': 29, 'rank': 27},
#   {'team': 'Washington Capitals', 'standings': 1, 'rank': 4},
#   {'team': 'Winnipeg Jets', 'standings': 20, 'rank': 21}],
#  '2018': [{'team': 'Anaheim Ducks', 'standings': 9, 'rank': 17},
#   {'team': 'Arizona Coyotes', 'standings': 29, 'rank': 26},
#   {'team': 'Boston Bruins', 'standings': 4, 'rank': 8},
#   {'team': 'Buffalo Sabres', 'standings': 31, 'rank': 30},
#   {'team': 'Calgary Flames', 'standings': 20, 'rank': 21},
#   {'team': 'Carolina Hurricanes', 'standings': 21, 'rank': 23},
#   {'team': 'Chicago Blackhawks', 'standings': 25, 'rank': 29},
#   {'team': 'Colorado Avalanche', 'standings': 17, 'rank': 5},
#   {'team': 'Columbus Blue Jackets', 'standings': 14, 'rank': 15},
#   {'team': 'Dallas Stars', 'standings': 19, 'rank': 19},
#   {'team': 'Detroit Red Wings', 'standings': 27, 'rank': 27},
#   {'team': 'Edmonton Oilers', 'standings': 23, 'rank': 22},
#   {'team': 'Florida Panthers', 'standings': 16, 'rank': 10},
#   {'team': 'Los Angeles Kings', 'standings': 12, 'rank': 11},
#   {'team': 'Minnesota Wild', 'standings': 8, 'rank': 12},
#   {'team': 'Montreal Canadiens', 'standings': 28, 'rank': 31},
#   {'team': 'Nashville Predators', 'standings': 1, 'rank': 4},
#   {'team': 'New Jersey Devils', 'standings': 15, 'rank': 2},
#   {'team': 'New York Islanders', 'standings': 22, 'rank': 24},
#   {'team': 'New York Rangers', 'standings': 24, 'rank': 25},
#   {'team': 'Ottawa Senators', 'standings': 30, 'rank': 28},
#   {'team': 'Philadelphia Flyers', 'standings': 13, 'rank': 16},
#   {'team': 'Pittsburgh Penguins', 'standings': 10, 'rank': 18},
#   {'team': 'San Jose Sharks', 'standings': 11, 'rank': 14},
#   {'team': 'St Louis Blues', 'standings': 18, 'rank': 13},
#   {'team': 'Tampa Bay Lightning', 'standings': 3, 'rank': 6},
#   {'team': 'Toronto Maple Leafs', 'standings': 6, 'rank': 7},
#   {'team': 'Vancouver Canucks', 'standings': 26, 'rank': 20},
#   {'team': 'Vegas Golden Knights', 'standings': 5, 'rank': 1},
#   {'team': 'Washington Capitals', 'standings': 7, 'rank': 9},
#   {'team': 'Winnipeg Jets', 'standings': 2, 'rank': 3}],
#  '2019': [{'team': 'Anaheim Ducks', 'standings': 24, 'rank': 20},
#   {'team': 'Arizona Coyotes', 'standings': 18, 'rank': 9},
#   {'team': 'Boston Bruins', 'standings': 3, 'rank': 7},
#   {'team': 'Buffalo Sabres', 'standings': 27, 'rank': 29},
#   {'team': 'Calgary Flames', 'standings': 2, 'rank': 3},
#   {'team': 'Carolina Hurricanes', 'standings': 11, 'rank': 6},
#   {'team': 'Chicago Blackhawks', 'standings': 20, 'rank': 18},
#   {'team': 'Colorado Avalanche', 'standings': 17, 'rank': 23},
#   {'team': 'Columbus Blue Jackets', 'standings': 13, 'rank': 11},
#   {'team': 'Dallas Stars', 'standings': 15, 'rank': 14},
#   {'team': 'Detroit Red Wings', 'standings': 28, 'rank': 12},
#   {'team': 'Edmonton Oilers', 'standings': 25, 'rank': 27},
#   {'team': 'Florida Panthers', 'standings': 19, 'rank': 25},
#   {'team': 'Los Angeles Kings', 'standings': 30, 'rank': 30},
#   {'team': 'Minnesota Wild', 'standings': 21, 'rank': 28},
#   {'team': 'Montreal Canadiens', 'standings': 14, 'rank': 5},
#   {'team': 'Nashville Predators', 'standings': 7, 'rank': 10},
#   {'team': 'New Jersey Devils', 'standings': 29, 'rank': 31},
#   {'team': 'New York Islanders', 'standings': 5, 'rank': 2},
#   {'team': 'New York Rangers', 'standings': 26, 'rank': 26},
#   {'team': 'Ottawa Senators', 'standings': 31, 'rank': 24},
#   {'team': 'Philadelphia Flyers', 'standings': 22, 'rank': 22},
#   {'team': 'Pittsburgh Penguins', 'standings': 9, 'rank': 19},
#   {'team': 'San Jose Sharks', 'standings': 6, 'rank': 15},
#   {'team': 'St Louis Blues', 'standings': 12, 'rank': 4},
#   {'team': 'Tampa Bay Lightning', 'standings': 1, 'rank': 1},
#   {'team': 'Toronto Maple Leafs', 'standings': 8, 'rank': 13},
#   {'team': 'Vancouver Canucks', 'standings': 23, 'rank': 16},
#   {'team': 'Vegas Golden Knights', 'standings': 16, 'rank': 21},
#   {'team': 'Washington Capitals', 'standings': 4, 'rank': 8},
#   {'team': 'Winnipeg Jets', 'standings': 10, 'rank': 17}]}

# %%
for k,v in all_season_results_dict.items():
#     print(k)
    all_season_results_dict[k] = []
#     if len(k) ==4:
    for z,x in v.items():
        all_season_results_dict[k].append({'team':z,'result':v[z]})
# all_season_results_dict.pop('_id')
all_season_results_dict
# Out:
# {'2010': [{'team': 'Anaheim Ducks', 'result': -1014},
#   {'team': 'Arizona Coyotes', 'result': 4483},
#   {'team': 'Boston Bruins', 'result': -11143},
#   {'team': 'Buffalo Sabres', 'result': -3895},
#   {'team': 'Calgary Flames', 'result': -4751},
#   {'team': 'Carolina Hurricanes', 'result': -7690},
#   {'team': 'Chicago Blackhawks', 'result': 4491},
#   {'team': 'Colorado Avalanche', 'result': 4758},
#   {'team': 'Columbus Blue Jackets', 'result': -17722},
#   {'team': 'Dallas Stars', 'result': -6722},
#   {'team': 'Detroit Red Wings', 'result': -1485},
#   {'team': 'Edmonton Oilers', 'result': -14665},
#   {'team': 'Florida Panthers', 'result': -8305},
#   {'team': 'Los Angeles Kings', 'result': 7151},
#   {'team': 'Minnesota Wild', 'result': 26},
#   {'team': 'Montreal Canadiens', 'result': -2401},
#   {'team': 'Nashville Predators', 'result': 10024},
#   {'team': 'New Jersey Devils', 'result': 5361},
#   {'team': 'New York Rangers', 'result': -8517},
#   {'team': 'New York Islanders', 'result': -2901},
#   {'team': 'Ottawa Senators', 'result': 6450},
#   {'team': 'Philadelphia Flyers', 'result': -6025},
#   {'team': 'Pittsburgh Penguins', 'result': -3326},
#   {'team': 'San Jose Sharks', 'result': -634},
#   {'team': 'St Louis Blues', 'result': 10680},
#   {'team': 'Tampa Bay Lightning', 'result': -15407},
#   {'team': 'Toronto Maple Leafs', 'result': -16664},
#   {'team': 'Vancouver Canucks', 'result': 5963},
#   {'team': 'Vegas Golden Knights', 'result': 0},
#   {'team': 'Washington Capitals', 'result': 5616},
#   {'team': 'Winnipeg Jets', 'result': -4688}],
#  '2011': [{'team': 'Anaheim Ducks', 'result': 12052},
#   {'team': 'Arizona Coyotes', 'result': 8211},
#   {'team': 'Boston Bruins', 'result': 2664},
#   {'team': 'Buffalo Sabres', 'result': 120},
#   {'team': 'Calgary Flames', 'result': -6133},
#   {'team': 'Carolina Hurricanes', 'result': -9213},
#   {'team': 'Chicago Blackhawks', 'result': -3932},
#   {'team': 'Colorado Avalanche', 'result': -19610},
#   {'team': 'Columbus Blue Jackets', 'result': -10029},
#   {'team': 'Dallas Stars', 'result': 3187},
#   {'team': 'Detroit Red Wings', 'result': -222},
#   {'team': 'Edmonton Oilers', 'result': -20413},
#   {'team': 'Florida Panthers', 'result': -17981},
#   {'team': 'Los Angeles Kings', 'result': 2441},
#   {'team': 'Minnesota Wild', 'result': -792},
#   {'team': 'Montreal Canadiens', 'result': 5605},
#   {'team': 'Nashville Predators', 'result': 6641},
#   {'team': 'New Jersey Devils', 'result': -6075},
#   {'team': 'New York Rangers', 'result': 4780},
#   {'team': 'New York Islanders', 'result': -12454},
#   {'team': 'Ottawa Senators', 'result': -10907},
#   {'team': 'Philadelphia Flyers', 'result': 1619},
#   {'team': 'Pittsburgh Penguins', 'result': 5360},
#   {'team': 'San Jose Sharks', 'result': 368},
#   {'team': 'St Louis Blues', 'result': -5638},
#   {'team': 'Tampa Bay Lightning', 'result': 3812},
#   {'team': 'Toronto Maple Leafs', 'result': -5790},
#   {'team': 'Vancouver Canucks', 'result': 4668},
#   {'team': 'Vegas Golden Knights', 'result': 0},
#   {'team': 'Washington Capitals', 'result': 557},
#   {'team': 'Winnipeg Jets', 'result': 883}],
#  '2012': [{'team': 'Anaheim Ducks', 'result': -11566},
#   {'team': 'Arizona Coyotes', 'result': 1919},
#   {'team': 'Boston Bruins', 'result': -1636},
#   {'team': 'Buffalo Sabres', 'result': -6393},
#   {'team': 'Calgary Flames', 'result': -6693},
#   {'team': 'Carolina Hurricanes', 'result': -9274},
#   {'team': 'Chicago Blackhawks', 'result': -1282},
#   {'team': 'Colorado Avalanche', 'result': 9142},
#   {'team': 'Columbus Blue Jackets', 'result': -13474},
#   {'team': 'Dallas Stars', 'result': 2394},
#   {'team': 'Detroit Red Wings', 'result': -1486},
#   {'team': 'Edmonton Oilers', 'result': -5744},
#   {'team': 'Florida Panthers', 'result': -5096},
#   {'team': 'Los Angeles Kings', 'result': -6410},
#   {'team': 'Minnesota Wild', 'result': -8119},
#   {'team': 'Montreal Canadiens', 'result': -18304},
#   {'team': 'Nashville Predators', 'result': 3226},
#   {'team': 'New Jersey Devils', 'result': 13343},
#   {'team': 'New York Rangers', 'result': 8502},
#   {'team': 'New York Islanders', 'result': -3428},
#   {'team': 'Ottawa Senators', 'result': 3606},
#   {'team': 'Philadelphia Flyers', 'result': 473},
#   {'team': 'Pittsburgh Penguins', 'result': 4457},
#   {'team': 'San Jose Sharks', 'result': -2306},
#   {'team': 'St Louis Blues', 'result': -4844},
#   {'team': 'Tampa Bay Lightning', 'result': -3496},
#   {'team': 'Toronto Maple Leafs', 'result': -13489},
#   {'team': 'Vancouver Canucks', 'result': 4543},
#   {'team': 'Vegas Golden Knights', 'result': 0},
#   {'team': 'Washington Capitals', 'result': -5864},
#   {'team': 'Winnipeg Jets', 'result': -4204}],
#  '2013': [{'team': 'Anaheim Ducks', 'result': 10973},
#   {'team': 'Arizona Coyotes', 'result': -5347},
#   {'team': 'Boston Bruins', 'result': -3001},
#   {'team': 'Buffalo Sabres', 'result': -2222},
#   {'team': 'Calgary Flames', 'result': -5544},
#   {'team': 'Carolina Hurricanes', 'result': -9155},
#   {'team': 'Chicago Blackhawks', 'result': 10398},
#   {'team': 'Colorado Avalanche', 'result': -13850},
#   {'team': 'Columbus Blue Jackets', 'result': 8049},
#   {'team': 'Dallas Stars', 'result': 2412},
#   {'team': 'Detroit Red Wings', 'result': -2654},
#   {'team': 'Edmonton Oilers', 'result': -9853},
#   {'team': 'Florida Panthers', 'result': -13398},
#   {'team': 'Los Angeles Kings', 'result': -3289},
#   {'team': 'Minnesota Wild', 'result': 1992},
#   {'team': 'Montreal Canadiens', 'result': 6436},
#   {'team': 'Nashville Predators', 'result': -17398},
#   {'team': 'New Jersey Devils', 'result': -12689},
#   {'team': 'New York Rangers', 'result': -2696},
#   {'team': 'New York Islanders', 'result': 1374},
#   {'team': 'Ottawa Senators', 'result': 1847},
#   {'team': 'Philadelphia Flyers', 'result': -2886},
#   {'team': 'Pittsburgh Penguins', 'result': 12925},
#   {'team': 'San Jose Sharks', 'result': -3543},
#   {'team': 'St Louis Blues', 'result': 2334},
#   {'team': 'Tampa Bay Lightning', 'result': -14468},
#   {'team': 'Toronto Maple Leafs', 'result': 3934},
#   {'team': 'Vancouver Canucks', 'result': -3592},
#   {'team': 'Vegas Golden Knights', 'result': 0},
#   {'team': 'Washington Capitals', 'result': 4461},
#   {'team': 'Winnipeg Jets', 'result': -727}],
#  '2014': [{'team': 'Anaheim Ducks', 'result': 7832},
#   {'team': 'Arizona Coyotes', 'result': -8605},
#   {'team': 'Boston Bruins', 'result': 7452},
#   {'team': 'Buffalo Sabres', 'result': -30165},
#   {'team': 'Calgary Flames', 'result': 2193},
#   {'team': 'Carolina Hurricanes', 'result': -5587},
#   {'team': 'Chicago Blackhawks', 'result': -4119},
#   {'team': 'Colorado Avalanche', 'result': 13788},
#   {'team': 'Columbus Blue Jackets', 'result': -136},
#   {'team': 'Dallas Stars', 'result': -3424},
#   {'team': 'Detroit Red Wings', 'result': -6168},
#   {'team': 'Edmonton Oilers', 'result': -17312},
#   {'team': 'Florida Panthers', 'result': -14280},
#   {'team': 'Los Angeles Kings', 'result': 1036},
#   {'team': 'Minnesota Wild', 'result': -206},
#   {'team': 'Montreal Canadiens', 'result': 5272},
#   {'team': 'Nashville Predators', 'result': 4285},
#   {'team': 'New Jersey Devils', 'result': -9205},
#   {'team': 'New York Rangers', 'result': 4721},
#   {'team': 'New York Islanders', 'result': -3289},
#   {'team': 'Ottawa Senators', 'result': -10302},
#   {'team': 'Philadelphia Flyers', 'result': 1658},
#   {'team': 'Pittsburgh Penguins', 'result': 4589},
#   {'team': 'San Jose Sharks', 'result': -634},
#   {'team': 'St Louis Blues', 'result': 385},
#   {'team': 'Tampa Bay Lightning', 'result': 6058},
#   {'team': 'Toronto Maple Leafs', 'result': -7029},
#   {'team': 'Vancouver Canucks', 'result': -13874},
#   {'team': 'Vegas Golden Knights', 'result': 0},
#   {'team': 'Washington Capitals', 'result': -8994},
#   {'team': 'Winnipeg Jets', 'result': -2105}],
#  '2015': [{'team': 'Anaheim Ducks', 'result': 9781},
#   {'team': 'Arizona Coyotes', 'result': -24203},
#   {'team': 'Boston Bruins', 'result': -8878},
#   {'team': 'Buffalo Sabres', 'result': -13270},
#   {'team': 'Calgary Flames', 'result': 11614},
#   {'team': 'Carolina Hurricanes', 'result': -15498},
#   {'team': 'Chicago Blackhawks', 'result': -1803},
#   {'team': 'Colorado Avalanche', 'result': 901},
#   {'team': 'Columbus Blue Jackets', 'result': 9602},
#   {'team': 'Dallas Stars', 'result': -198},
#   {'team': 'Detroit Red Wings', 'result': -5921},
#   {'team': 'Edmonton Oilers', 'result': -19948},
#   {'team': 'Florida Panthers', 'result': -1130},
#   {'team': 'Los Angeles Kings', 'result': -13071},
#   {'team': 'Minnesota Wild', 'result': 1618},
#   {'team': 'Montreal Canadiens', 'result': 6336},
#   {'team': 'Nashville Predators', 'result': 1857},
#   {'team': 'New Jersey Devils', 'result': -17784},
#   {'team': 'New York Rangers', 'result': 11204},
#   {'team': 'New York Islanders', 'result': 5021},
#   {'team': 'Ottawa Senators', 'result': 3413},
#   {'team': 'Philadelphia Flyers', 'result': -12839},
#   {'team': 'Pittsburgh Penguins', 'result': -11883},
#   {'team': 'San Jose Sharks', 'result': -6668},
#   {'team': 'St Louis Blues', 'result': 2813},
#   {'team': 'Tampa Bay Lightning', 'result': 2620},
#   {'team': 'Toronto Maple Leafs', 'result': -18481},
#   {'team': 'Vancouver Canucks', 'result': 6465},
#   {'team': 'Vegas Golden Knights', 'result': 0},
#   {'team': 'Washington Capitals', 'result': 3124},
#   {'team': 'Winnipeg Jets', 'result': 4516}],
#  '2016': [{'team': 'Anaheim Ducks', 'result': 985},
#   {'team': 'Arizona Coyotes', 'result': -1895},
#   {'team': 'Boston Bruins', 'result': -4533},
#   {'team': 'Buffalo Sabres', 'result': 1274},
#   {'team': 'Calgary Flames', 'result': -6645},
#   {'team': 'Carolina Hurricanes', 'result': -8433},
#   {'team': 'Chicago Blackhawks', 'result': -1965},
#   {'team': 'Colorado Avalanche', 'result': 3023},
#   {'team': 'Columbus Blue Jackets', 'result': -8468},
#   {'team': 'Dallas Stars', 'result': 9670},
#   {'team': 'Detroit Red Wings', 'result': -6053},
#   {'team': 'Edmonton Oilers', 'result': -14430},
#   {'team': 'Florida Panthers', 'result': 4064},
#   {'team': 'Los Angeles Kings', 'result': -87},
#   {'team': 'Minnesota Wild', 'result': -11802},
#   {'team': 'Montreal Canadiens', 'result': -7677},
#   {'team': 'Nashville Predators', 'result': -7564},
#   {'team': 'New Jersey Devils', 'result': 465},
#   {'team': 'New York Rangers', 'result': -1825},
#   {'team': 'New York Islanders', 'result': -1291},
#   {'team': 'Ottawa Senators', 'result': -6118},
#   {'team': 'Philadelphia Flyers', 'result': 1261},
#   {'team': 'Pittsburgh Penguins', 'result': 4970},
#   {'team': 'San Jose Sharks', 'result': 743},
#   {'team': 'St Louis Blues', 'result': 7635},
#   {'team': 'Tampa Bay Lightning', 'result': -3415},
#   {'team': 'Toronto Maple Leafs', 'result': -13961},
#   {'team': 'Vancouver Canucks', 'result': -13117},
#   {'team': 'Vegas Golden Knights', 'result': 0},
#   {'team': 'Washington Capitals', 'result': 10364},
#   {'team': 'Winnipeg Jets', 'result': -10032}],
#  '2017': [{'team': 'Anaheim Ducks', 'result': 1034},
#   {'team': 'Arizona Coyotes', 'result': -4856},
#   {'team': 'Boston Bruins', 'result': -4649},
#   {'team': 'Buffalo Sabres', 'result': -8112},
#   {'team': 'Calgary Flames', 'result': 2930},
#   {'team': 'Carolina Hurricanes', 'result': -8834},
#   {'team': 'Chicago Blackhawks', 'result': 5510},
#   {'team': 'Colorado Avalanche', 'result': -27157},
#   {'team': 'Columbus Blue Jackets', 'result': 10406},
#   {'team': 'Dallas Stars', 'result': -13816},
#   {'team': 'Detroit Red Wings', 'result': -11306},
#   {'team': 'Edmonton Oilers', 'result': 2394},
#   {'team': 'Florida Panthers', 'result': -12989},
#   {'team': 'Los Angeles Kings', 'result': -10217},
#   {'team': 'Minnesota Wild', 'result': 7316},
#   {'team': 'Montreal Canadiens', 'result': 2920},
#   {'team': 'Nashville Predators', 'result': -6069},
#   {'team': 'New Jersey Devils', 'result': -22134},
#   {'team': 'New York Rangers', 'result': 6523},
#   {'team': 'New York Islanders', 'result': 1815},
#   {'team': 'Ottawa Senators', 'result': 7476},
#   {'team': 'Philadelphia Flyers', 'result': -4524},
#   {'team': 'Pittsburgh Penguins', 'result': -515},
#   {'team': 'San Jose Sharks', 'result': -1665},
#   {'team': 'St Louis Blues', 'result': 3973},
#   {'team': 'Tampa Bay Lightning', 'result': -3833},
#   {'team': 'Toronto Maple Leafs', 'result': -4229},
#   {'team': 'Vancouver Canucks', 'result': -12444},
#   {'team': 'Vegas Golden Knights', 'result': 0},
#   {'team': 'Washington Capitals', 'result': 6921},
#   {'team': 'Winnipeg Jets', 'result': -5473}],
#  '2018': [{'team': 'Anaheim Ducks', 'result': -2438},
#   {'team': 'Arizona Coyotes', 'result': -14737},
#   {'team': 'Boston Bruins', 'result': 5542},
#   {'team': 'Buffalo Sabres', 'result': -18266},
#   {'team': 'Calgary Flames', 'result': -8894},
#   {'team': 'Carolina Hurricanes', 'result': -11178},
#   {'team': 'Chicago Blackhawks', 'result': -17925},
#   {'team': 'Colorado Avalanche', 'result': 7995},
#   {'team': 'Columbus Blue Jackets', 'result': -1054},
#   {'team': 'Dallas Stars', 'result': -3408},
#   {'team': 'Detroit Red Wings', 'result': -16155},
#   {'team': 'Edmonton Oilers', 'result': -10296},
#   {'team': 'Florida Panthers', 'result': 1882},
#   {'team': 'Los Angeles Kings', 'result': 685},
#   {'team': 'Minnesota Wild', 'result': -43},
#   {'team': 'Montreal Canadiens', 'result': -25525},
#   {'team': 'Nashville Predators', 'result': 8869},
#   {'team': 'New Jersey Devils', 'result': 11206},
#   {'team': 'New York Rangers', 'result': -14178},
#   {'team': 'New York Islanders', 'result': -13867},
#   {'team': 'Ottawa Senators', 'result': -17092},
#   {'team': 'Philadelphia Flyers', 'result': -1878},
#   {'team': 'Pittsburgh Penguins', 'result': -3176},
#   {'team': 'San Jose Sharks', 'result': -901},
#   {'team': 'St Louis Blues', 'result': -717},
#   {'team': 'Tampa Bay Lightning', 'result': 6143},
#   {'team': 'Toronto Maple Leafs', 'result': 5992},
#   {'team': 'Vancouver Canucks', 'result': -6536},
#   {'team': 'Vegas Golden Knights', 'result': 17370},
#   {'team': 'Washington Capitals', 'result': 3449},
#   {'team': 'Winnipeg Jets', 'result': 10409}],
#  '2019': [{'team': 'Anaheim Ducks', 'result': -6864},
#   {'team': 'Arizona Coyotes', 'result': 1881},
#   {'team': 'Boston Bruins', 'result': 2610},
#   {'team': 'Buffalo Sabres', 'result': -12463},
#   {'team': 'Calgary Flames', 'result': 5033},
#   {'team': 'Carolina Hurricanes', 'result': 3117},
#   {'team': 'Chicago Blackhawks', 'result': -4575},
#   {'team': 'Colorado Avalanche', 'result': -8214},
#   {'team': 'Columbus Blue Jackets', 'result': -498},
#   {'team': 'Dallas Stars', 'result': -2925},
#   {'team': 'Detroit Red Wings', 'result': -1888},
#   {'team': 'Edmonton Oilers', 'result': -11750},
#   {'team': 'Florida Panthers', 'result': -9342},
#   {'team': 'Los Angeles Kings', 'result': -14065},
#   {'team': 'Minnesota Wild', 'result': -11858},
#   {'team': 'Montreal Canadiens', 'result': 3945},
#   {'team': 'Nashville Predators', 'result': 128},
#   {'team': 'New Jersey Devils', 'result': -15618},
#   {'team': 'New York Rangers', 'result': -9403},
#   {'team': 'New York Islanders', 'result': 12676},
#   {'team': 'Ottawa Senators', 'result': -8583},
#   {'team': 'Philadelphia Flyers', 'result': -8160},
#   {'team': 'Pittsburgh Penguins', 'result': -6328},
#   {'team': 'San Jose Sharks', 'result': -3114},
#   {'team': 'St Louis Blues', 'result': 4671},
#   {'team': 'Tampa Bay Lightning', 'result': 18130},
#   {'team': 'Toronto Maple Leafs', 'result': -2444},
#   {'team': 'Vancouver Canucks', 'result': -3180},
#   {'team': 'Vegas Golden Knights', 'result': -7480},
#   {'team': 'Washington Capitals', 'result': 1945},
#   {'team': 'Winnipeg Jets', 'result': -3801}]}

# %%
client = MongoClient()
db = client.NHL_stats.all_results
db.info.remove()
db.info.insert(results_and_standing_dict)
# Out:
# C:\Users\Ryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Ryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   after removing the cwd from sys.path.
# ObjectId('5ce3488d14eedf318c51bb76')

# %%
all_season_results_dict
# for k,v in all_season_results_dict.items():
#     for z,x in v.items():
#         if -14000 < x < -13000:
#             print(x, k)
client = MongoClient()
db = client.NHL_stats.yearly_results
db.info.remove()
db.info.insert(all_season_results_dict)
# Out:
# C:\Users\Ryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#
# C:\Users\Ryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':
# ObjectId('5ce41f0914eedf318c51bb85')

# %%
client = MongoClient()
db = client.NHL_stats.vs_results
db.info.remove()
db.info.insert(standings_vs_rank)
# Out:
# C:\Users\Ryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Ryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   after removing the cwd from sys.path.
# ObjectId('5ce443b814eedf318c51bb87')

# %%
# X = ml_df[['Date_month','Date_year','Date_day','Home','Home_line','Away','Away_line']]
# y = ml_df[['Home_win']]
# X_train, X_test, y_train, y_test = train_test_split(X, y)

# classifiers = [
# #     KNeighborsClassifier(3),
# #     SVC(kernel="rbf", C=0.025, probability=True),
# #     NuSVC(probability=True),
# #     DecisionTreeClassifier(),
#     RandomForestClassifier(),
#     AdaBoostClassifier(),
#     GradientBoostingClassifier(criterion='friedman_mse', init=None,
#  learning_rate=0.01,n_estimators=100,max_depth=3),
#     GaussianNB(),
#     LinearDiscriminantAnalysis(),
#     QuadraticDiscriminantAnalysis()]

# # Logging for Visual Comparison
# log_cols=["Classifier", "Accuracy", "Log Loss"]
# log = pd.DataFrame(columns=log_cols)

# for clf in classifiers:
#     clf.fit(X_train, y_train)
#     name = clf.__class__.__name__
    
#     print("="*30)
#     print(name)
    
#     print('****Results****')
#     train_predictions = clf.predict(X_test)
#     acc = accuracy_score(y_test, train_predictions)
#     print("Accuracy: {:.4%}".format(acc))
    
#     train_predictions = clf.predict_proba(X_test)
#     ll = log_loss(y_test, train_predictions)
#     print("Log Loss: {}".format(ll))
    
#     log_entry = pd.DataFrame([[name, acc*100, ll]], columns=log_cols)
#     log = log.append(log_entry)
    
# print("="*30)

# clf = GradientBoostingClassifier()
# clf.fit(X_train, y_train)
# train_predictions = clf.predict(X_test)
# acc = accuracy_score(y_test, train_predictions)
# print("Accuracy: {:.4%}".format(acc))
